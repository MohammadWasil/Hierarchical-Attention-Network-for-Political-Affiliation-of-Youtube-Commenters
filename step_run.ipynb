# %%
import time, requests, re
from urllib.parse import urlparse
from bs4 import BeautifulSoup
from tqdm.notebook import tqdm
from collections import defaultdict
from tweepy import OAuthHandler, API

from urllib.parse import parse_qs, quote, unquote, urlparse
import pandas as pd
import pprint
import json

from difflib import SequenceMatcher
import time, requests, re, random, tldextract

from googleapiclient.discovery import build

# %%
import yaml, os
directory_path = "D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/"

# load config_KEYS.yaml file
with open(os.path.join(directory_path, "utility/config_KEYS.yml"), "r") as ymlfile:
    cfg =  yaml.safe_load(ymlfile)

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
pp = pprint.PrettyPrinter(width=41, compact=True)

# %%
# Authenticate to Twitter
# Authenticate to Twitter
auth = OAuthHandler(cfg["API_KEYS"], cfg["API_SECRET_KEYS"])
auth.set_access_token(cfg["ACCESS_TOKEN"], cfg["ACCESS_TOKEN_SECRET"])

api = API(auth)

if api.verify_credentials() == False:
    print("The user credentials are invalid.")
else:
    print("The user credentials are valid.")
# Out:
# The user credentials are valid.

# %%
# Authenticate to youtube
youtube_service = build('youtube', 'v3', developerKey=cfg["YOUTUBE_KEY"])

# %% [markdown]
# pages to scrap for list of news channels.
#
# https://mediabiasfactcheck.com/left/  <Br>
# https://mediabiasfactcheck.com/leftcenter/ <Br>
# https://mediabiasfactcheck.com/center/ <Br>
# https://mediabiasfactcheck.com/right-center/ <Br>
# https://mediabiasfactcheck.com/right/ <Br>
#
# https://mediabiasfactcheck.com/fake-news/ <Br>

# %%
headers = requests.utils.default_headers()

headers.update(
    {
        'User-Agent': 'My User Agent 1.0',
    }
)

# %%
ideology_pages = ['left', 'leftcenter', 'center', 'right-center', 'right', 'fake-news']
bias_rating = ['left', 'center-left', 'center', 'center-right', 'right', 'fake-news']

links = []
names = []
bias_ratings = []
for i, pages in enumerate(ideology_pages):
    tags_ignored = 0
    
    MBFC_SOURCE_URL = "https://mediabiasfactcheck.com/{}/".format(pages)
    #print(MBFC_SOURCE_URL)
    response = requests.get(MBFC_SOURCE_URL)
    soup = BeautifulSoup(response.text, 'lxml')

    #list_pages = soup.find( "table", {"id":"mbfc-table"} ).find_all("tr")
    table = soup.find('table', attrs={'id':'mbfc-table'}).find("tbody")
    list_rows = table.find_all('tr')


    for row_idx, row in enumerate(list_rows):
        try:
            link = row.find('td').find('a', href=True).get('href')
            name = row.find('td').text
            
            names.append(name)
            links.append(link)
            bias_ratings.append(bias_rating[i])
            
        except:
            tags_ignored += 1
            #print("ignoring one tag")
    #news_channel_list = news_channel_list.reset_index(drop=True)
    print("Tags ignored for {} ideology news channels list: {}".format(pages, tags_ignored))

news_channel_list = pd.DataFrame(
    {'Name': names,
     'Link': links,
     'Bias Rating': bias_ratings,
     'Country': None,
     'Website': None
    })
    
# requesting each websites
for j, link in enumerate(news_channel_list["Link"]):
    #link = "https://mediabiasfactcheck.com/american-united-separation-church-state/"
    response = requests.get(link)
    soup = BeautifulSoup(response.text, 'lxml')

    # get the p tag with Bias Rating and country.
    news_info = soup.find("div", {"class" : "entry-content clearfix"})

    try:
        news_channel_information = news_info.find_all(text = re.compile('Country:'))[0].parent.get_text(strip=False).split("\n")

        for n_i in news_channel_information:
            if n_i.split(":")[0] == "Country":
                country = n_i.split(":")[1].strip()
                if country != "":
                    #country.append(n_i.split(":")[1].strip() )
                    news_channel_list.loc[j, "Country"] = country
                else:
                    #print("country is empty")
                    raise 

        print("News channel Index : ", j, " Done!")
    except:
        country_ = "NA"
        country_pattern = r'Country:\s[a-zA-Z]+'
        try:
            for line in news_info.text.split('\n'):
                if bool(re.match(country_pattern, line)):
                    #country = line.rstrip().split(':')[1].split('(')[0].strip()
                    country_ = line.split(":")[1].strip()
                    #country.append(country_)
                    news_channel_list.loc[j, "Country"] = country_

            if country_ == "NA":
                print("News channel Index : ", j, " Not Done!")
            else:
                print("News channel Index : ", j, " Done by 2nd method!")
        except:
            print("The MBFC website for {} does not exists!".format(news_channel_list["Name"][j]))

    try:
        source = news_info.find_all(text = re.compile('Source:'))[0].parent.find('a', href=True).get('href')
        #news_website.append(source)
        news_channel_list.loc[j, "Website"] = source
        print("News Channel source for Index : ", j, " Done!")

    except:
        source_ = "NA"
        source_pattern = r'Sources?:\shttps?://(?:[-\w.]|(?:%[\da-fA-F]{2}))+'
        try:
            for line in news_info.text.split('\n'):
                if bool(re.match(source_pattern, line)):
                    source_ = line.split(":", 1)[1].strip().rstrip(" ")
                    #news_website.append(source_)
                    news_channel_list.loc[j, "Website"] = source_

            if source_ == "NA":
                print("News channel source Index : ", j, " Not Done!")
            else:
                print("News channel source Index : ", j, " Done by 2nd method!")
        except:
            print("The MBFC website for {} does not exists!".format(news_channel_list["Name"][j]))
# Out:
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# ignoring one tag
# News channel Index :  0  Done!
# News Channel source for Index :  0  Done!
# News channel Index :  1  Done!
# News Channel source for Index :  1  Done!
# News channel Index :  2  Done!
# News Channel source for Index :  2  Done!
# News channel Index :  3  Done!
# News Channel source for Index :  3  Done!
# News channel Index :  4  Done!
# News Channel source for Index :  4  Done!
# News channel Index :  5  Done!
# News Channel source for Index :  5  Done!
# News channel Index :  6  Done!
# News Channel source for Index :  6  Done!
# News channel Index :  7  Done!
# News Channel source for Index :  7  Done!
# News channel Index :  8  Done!
# News Channel source for Index :  8  Done!
# News channel Index :  9  Done!
# News Channel source for Index :  9  Done!
# News channel Index :  10  Done!
# News Channel source for Index :  10  Done!
# News channel Index :  11  Done!
# News Channel source for Index :  11  Done!
# News channel Index :  12  Done!
# News Channel source for Index :  12  Done!
# News channel Index :  13  Done!
# News Channel source for Index :  13  Done!
# News channel Index :  14  Done!
# News Channel source for Index :  14  Done!
# News channel Index :  15  Done!
# News Channel source for Index :  15  Done!
# News channel Index :  16  Done!
# News Channel source for Index :  16  Done!
# News channel Index :  17  Done!
# News Channel source for Index :  17  Done!
# News channel Index :  18  Done!
# News Channel source for Index :  18  Done!
# News channel Index :  19  Done!
# News Channel source for Index :  19  Done!
# News channel Index :  20  Done!
# News Channel source for Index :  20  Done!
# News channel Index :  21  Done!
# News Channel source for Index :  21  Done!
# News channel Index :  22  Done!
# News Channel source for Index :  22  Done!
# News channel Index :  23  Done!
# News Channel source for Index :  23  Done!
# News channel Index :  24  Done!
# News Channel source for Index :  24  Done!
# News channel Index :  25  Done!
# News Channel source for Index :  25  Done!
# News Channel source for Index :  610  Done!
# News channel Index :  611  Done!
# News Channel source for Index :  611  Done!
# News channel Index :  612  Done!
# News Channel source for Index :  612  Done!
# News channel Index :  613  Done by 2nd method!
# News Channel source for Index :  613  Done!
# News channel Index :  614  Done!
# News Channel source for Index :  614  Done!
# News channel Index :  615  Done!
# News Channel source for Index :  615  Done!
# News channel Index :  616  Done!
# News Channel source for Index :  616  Done!
# News channel Index :  617  Done!
# News Channel source for Index :  617  Done!
# News channel Index :  618  Done!
# News Channel source for Index :  618  Done!
# News channel Index :  619  Done!
# News Channel source for Index :  619  Done!
# News channel Index :  620  Done!
# News Channel source for Index :  620  Done!
# News channel Index :  621  Done!
# News Channel source for Index :  621  Done!
# News channel Index :  622  Done by 2nd method!
# News Channel source for Index :  622  Done!
# News channel Index :  623  Done by 2nd method!
# News Channel source for Index :  623  Done!
# News channel Index :  624  Done!
# News Channel source for Index :  624  Done!
# News channel Index :  625  Done!
# News Channel source for Index :  625  Done!
# News channel Index :  626  Done!
# News Channel source for Index :  626  Done!
# News channel Index :  627  Done!
# News Channel source for Index :  627  Done!
# News channel Index :  628  Done!
# News Channel source for Index :  628  Done!
# News channel Index :  629  Done by 2nd method!
# News Channel source for Index :  629  Done!
# News channel Index :  630  Done!
# News Channel source for Index :  630  Done!
# News channel Index :  631  Done!
# News Channel source for Index :  631  Done!
# News channel Index :  632  Done!
# News Channel source for Index :  632  Done!
# News channel Index :  633  Done!
# News Channel source for Index :  633  Done!
# News channel Index :  634  Done!
# News Channel source for Index :  634  Done!
# News channel Index :  635  Done!
# News Channel source for Index :  635  Done!
# News channel Index :  636  Done!
# News Channel source for Index :  636  Done!
# News channel Index :  637  Done!
# News channel source Index :  637  Not Done!
# News channel Index :  638  Done!
# News Channel source for Index :  638  Done!
# News channel Index :  639  Done!
# News Channel source for Index :  639  Done!
# News channel Index :  640  Done!
# News Channel source for Index :  640  Done!
# News channel Index :  641  Done!
# News Channel source for Index :  641  Done!
# News channel Index :  642  Done!
# News Channel source for Index :  642  Done!
# News channel Index :  643  Done!
# News Channel source for Index :  643  Done!
# News channel Index :  644  Done!
# News Channel source for Index :  644  Done!
# News channel Index :  645  Done!
# News Channel source for Index :  645  Done!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11380/1182299756.py in <module>
#      50     try:
# ---> 51         news_channel_information = news_info.find_all(text = re.compile('Country:'))[0].parent.get_text(strip=False).split("\n")
#      52
#
# AttributeError: 'NoneType' object has no attribute 'find_all'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_11380/1182299756.py in <module>
#      65         country_ = "NA"
#      66         country_pattern = r'Country:\s[a-zA-Z]+'
# ---> 67         for line in news_info.text.split('\n'):
#      68             if bool(re.match(country_pattern, line)):
#      69                 #country = line.rstrip().split(':')[1].split('(')[0].strip()
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
links = []
names = []
bias_ratings = []

tags_ignored = 0
MBFC_SOURCE_URL = "https://mediabiasfactcheck.com/{}/".format("fake-news")
#print(MBFC_SOURCE_URL)
response = requests.get(MBFC_SOURCE_URL)
soup = BeautifulSoup(response.text, 'lxml')

#list_pages = soup.find( "table", {"id":"mbfc-table"} ).find_all("tr")
table = soup.find('table', attrs={'id':'mbfc-table'}).find("tbody")
list_rows = table.find_all('tr')

for row_idx, row in tqdm(enumerate(list_rows)):
    try:
        link = row.find('td').find('a', href=True).get('href')
        name = row.find('td').text

        names.append(name)
        links.append(link)
        bias_ratings.append(bias_rating[i])

    except:
        tags_ignored += 1
        #print("ignoring one tag")
#news_channel_list = news_channel_list.reset_index(drop=True)
print("Tags ignored for {} ideology news channels list: {}".format("fake-news", tags_ignored))

news_channel_list = pd.DataFrame(
    {'Name': names,
     'Link': links,
     #'Bias Rating': bias_ratings,
     #'Country': None,
     #'Website': None
    })
# Out:
# 945it [00:00, 27001.04it/s]
# Tags ignored for fake-news ideology news channels list: 945

# %%
news_channel_list.to_csv("News channels.csv", encoding='utf-8', index=False)

# %%
news_channels = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/News channels.csv")

# %%
news_channels.head()
# Out:
#                                        Name  \
# 0                            Accountable.US
# 1                           Act.TV (act.tv)
# 2                               Aftonbladet
# 3                                    Al DIA
# 4  Alliance for Justice (AFJ) (www.afj.org)
#
#                                                 Link Bias Rating Country  \
# 0     https://mediabiasfactcheck.com/accountable-us/        left     USA
# 1             https://mediabiasfactcheck.com/act-tv/        left     USA
# 2        https://mediabiasfactcheck.com/aftonbladet/        left  Sweden
# 3             https://mediabiasfactcheck.com/al-dia/        left     USA
# 4  https://mediabiasfactcheck.com/alliance-for-ju...        left     USA
#
#                        Website
# 0  https://www.accountable.us/
# 1                http://act.tv
# 2   https://www.aftonbladet.se
# 3        https://aldianews.com
# 4         https://www.afj.org/

# %%
news_channels[news_channels["Website"] == "https://www.newsmax.com/"]
# Out:
#                            Name                                     Link  \
# 2860  Newsmax (www.newsmax.com)  https://mediabiasfactcheck.com/newsmax/
#
#      Bias Rating Country                   Website
# 2860   fake-news     USA  https://www.newsmax.com/

# %%
for index, website_links in enumerate(news_channels["Website"][2000:2010]):
    index = news_channels.index[news_channels["Website"] == website_links].tolist()[0]
    print(index, ":", website_links)
# Out:
# 2000 : https://www.srnnews.com/
# 2001 : https://www.sbsun.com
# 2002 : https://thestarphoenix.com
# 2003 : https://www.savannahnow.com/
# 2004 : https://www.scoperatings.com/
# 2005 : https://sofrep.com/
# 2006 : https://www.twincities.com/
# 2007 : https://www.studentnewsdaily.com/
# 2008 : https://www.tabletmag.com/
# 2009 : http://www.tallahassee.com/

# %%
def find_value(html, key, num_chars=2, separator='"'):
    pos_begin = html.find(key) + len(key) + num_chars
    pos_end = html.find(separator, pos_begin)
    return html[pos_begin: pos_end]

# %%
def check_youtube_for_website_link(soup, website_links, twitter_handle_selected):
    domain = get_domain(website_links)
    
    aid = soup.find('script',string=re.compile('ytInitialData')).text
    yt_about_page = json.loads(aid[20:-1])

    #description = yt_about_page['contents']['twoColumnBrowseResultsRenderer']['tabs'][5]['tabRenderer']['content']['sectionListRenderer']['contents'][0]['itemSectionRenderer']['contents'][0]['channelAboutFullMetadataRenderer']['description']['simpleText']

    #youtube_to_website_link = yt_about_page['contents']['twoColumnBrowseResultsRenderer']['tabs'][5]['tabRenderer']['content']['sectionListRenderer']['contents'][0]['itemSectionRenderer']['contents'][0]['channelAboutFullMetadataRenderer']['primaryLinks'][0]['navigationEndpoint']['urlEndpoint']['url']

    #twitter_handle_link = yt_about_page['contents']['twoColumnBrowseResultsRenderer']['tabs'][5]['tabRenderer']['content']['sectionListRenderer']['contents'][0]['itemSectionRenderer']['contents'][0]['channelAboutFullMetadataRenderer']['primaryLinks'][2]['navigationEndpoint']['urlEndpoint']['url']

    # we will use one of them to compare whether the youtube channel we got indeed belongs to that neews channel or not.
    #links_for_checking_authenticity = [youtube_to_website_link, twitter_handle_link]

    links = next(search_dict(yt_about_page, 'primaryLinks'), [])
    links_for_checking_authenticity = []
    for link in links:
        #pp.pprint(link)
        #print("********************")
        #print(link["navigationEndpoint"]["urlEndpoint"]["url"])
        links_for_checking_authenticity.append(link["navigationEndpoint"]["urlEndpoint"]["url"])

    #website_links = "https://aldianews.com"
    #twitter_handle_selected = "ALDIANews"
    for link in links_for_checking_authenticity:
        #print(link)
        redirected_link = parse_qs(unquote(urlparse(link).query))
        #print(redirected_link)
        if 'q' in redirected_link:
            if "http:" in redirected_link['q'][0]:
                redirected_url = get_domain(redirected_link['q'][0])
                #print(redirected_url)
            else:
                redirected_url = re.sub(r'(https?://)?(www.)?', '', redirected_link['q'][0]).split('/', 1)[0]
                #print(redirected_url)

            if "twitter.com" in redirected_link['q'][0]:
                match = re.search(r"^.*?\btwitter\.com/@?([^?/,\r\n]+)(?:[?/,].*)?$", redirected_link['q'][0])                   
                #print(match.group(1))
                if twitter_handle_selected == match.group(1):
                    #print(True)
                    return True
            elif redirected_url == domain:
                #print(True)
                return True
    # can add one more check - domain from description.
    # if we find domain in the description of the youtube about page, then also we can say
    # that we ahve matched the correct youtube channel for that news channel website
    description = next(search_dict(yt_about_page, 'description'), {})
    if len(description) > 0:
        #print(description)
        if domain in description["simpleText"]:
            print("yes, the domain is in the description!")
            return True
    return False

def check_twitter_for_website_link(website_domain, twitter_json):
    """
    To check if the twitter handle we are going to select would belongs to the news channel that we selected during that iteartion.
    website_domain : website that we selected from csv file.
    twitter_json : the html file in json format that we extracted using lookup_users() function.
    
    returns : Boolean
                True: if the twitter handle does belongs to the new channel.
                False: if the twitter handle does NOT belongs to the new channel.
    """
    print("checking ... ")
    if "entities" in twitter_json:
        if "url" in twitter_json["entities"]:
            if "urls" in twitter_json["entities"]["url"]:
                if isinstance(twitter_json["entities"]["url"]["urls"], list):
                    if len(twitter_json["entities"]["url"]["urls"]) > 0:
                        if "expanded_url" in twitter_json["entities"]["url"]["urls"][0]:
                            if twitter_json["entities"]["url"]["urls"][0]["expanded_url"] is not None:  
                                expanded_url = twitter_json["entities"]["url"]["urls"][0]["expanded_url"]
                                if get_domain(website_domain) == get_domain(expanded_url):
                                    if urlparse(get_domain(website_domain)).path == "" or urlparse(get_domain(website_domain)).path == "/":
                                        if urlparse(get_domain(expanded_url)).path == "" or urlparse(get_domain(expanded_url)).path == "/":
                                            print("True")
                                            return True
                                    elif urlparse(get_domain(website_domain)).path.strip("/") == urlparse(get_domain(expanded_url)).path.strip("/"):
                                        print("True")
                                        return True
    print("False")
    return False

def get_domain(url):
    """
    To get th domain form a link
    For eg. http://www.facebook.com -> get_domain("http://www.facebook.com") -> facebook.com
    From github:
    
    """
    return re.sub(r'www\d?.', '', urlparse(url.lower()).netloc.split(':')[0])

# %%
num_channels = 0
num_twitter_handle = 0
num_youtube_channels = 0
num_fail_attempts = 0
num_twitter_handle_to_review = 0

twitter_handle_sim_score = defaultdict(float)
new_channel_yt_twitter_sim = pd.DataFrame(columns=['Name', 'Bias Rating', 'Country', 'Website', 'Youtube Channel', 'Twitter Handle', 'Twitter Similarity'])

for index, website_links in enumerate(news_channels["Website"][450:451]):
    new_channel_yt_twitter_sim.loc[index, "Name"] = news_channels["Name"][index]
    new_channel_yt_twitter_sim.loc[index, "Bias Rating"] = news_channels["Bias Rating"][index]
    new_channel_yt_twitter_sim.loc[index, "Country"] = news_channels["Country"][index]
    new_channel_yt_twitter_sim.loc[index, "Website"] = news_channels["Website"][index]
    
    num_channels += 1
    try:
        print("idufghgf")
        twitter_handle = defaultdict(int)
        youtube_channel_id = defaultdict(int)
        youtube_channel_users = defaultdict(int)
        print("{} : {}".format(index, website_links))

        response = requests.get(website_links, headers = headers)
        soup = BeautifulSoup(response.text, 'lxml')

        # trying to find social media link, iei either youtube link or twitter handle.
        website_link = soup.find_all('a', href=True)

        for socialmedia_link in website_link:

            channel_link = socialmedia_link.get("href")

            if "twitter.com" in channel_link.lower():
                    if (bool(re.match(r'https://twitter.com/[\w@]+\??|/?$', channel_link)) and not bool(re.match(r'https://twitter.com/(intent|share|home|hashtag|search)/?', channel_link))
                        and not bool(re.match(r'https://twitter.com/[\w]+/status?', channel_link))):

                        # extract the twitter handle
                        #match = re.search(r'^.*?\btwitter\.com/@?(\w{1,15})(?:[?/,].*)?$', socialmedia_link.get("href").lower())
                        match = re.search(r"^.*?\btwitter\.com/@?([^?/,\r\n]+)(?:[?/,].*)?$", channel_link)                   
                        # increament the dictionary with that key as twiter handle
                        twitter_handle[match.group(1)] += 1
                        print("Twitter handle Dictionary: ", twitter_handle)

            if "youtube.com/" in channel_link:

                if (not(bool(re.match(r'https://www.youtube.com/watch?[\w]+/?', channel_link)))):

                    # it can be channel id or youtube user
                    # Example: 
                    # https://www. youtube.com/channel/UCUZHFZ9jIKrLroW8LcyJEQQ
                    # https://www.youtube.com/channel/UC_WSavcwZVE3ciFM8yCwkBw/
                    # https://www.youtube.com/channel/UCHdWMuH-IIveBWjIsOhK-dw/videos
                    # https://www.youtube.com/channel/UCXu7fg-_KdAoHY7bmahr9vg/featured
                    # https://www.youtube.com/channel/UCmX0gITcFMtmDSah8-wCChw/videos?view_as=subscriber    
                    if (bool(re.match(r'https://www.youtube.com/channel/[\w]+/?', channel_link))):

                        youtube_id = yt_id = re.split(r'/|\?', channel_link)[4]
                        youtube_id = re.split('[^a-zA-Z0-9_-]', youtube_id)[0]
                        print("Youtube Id", youtube_id)
                        youtube_channel_id[youtube_id] += 1

                    # Example: 
                    # https://www.youtube.com/c/AmericanBridgePAC
                    # https://www.youtube.com/c/cosmopolitan?sub_confirmation=1
                    elif (bool(re.match(r'https://www.youtube.com/c/[\w]+/?', channel_link))):
                        youtube_user = re.split(r'/|\?', channel_link)[4]
                        youtube_user = re.split('\W', youtube_user)[0]
                        print("Youtube User", youtube_user)
                        youtube_channel_users[youtube_user] += 1

                    # Example: 
                    # https://www.youtube.com/user/pontealdiatv
                    # https://www.youtube.com/user/blackamericaweb?sub_confirmation=1
                    elif(bool(re.match(r'https://www.youtube.com/user/[\w]+/?', channel_link))):
                        youtube_user = re.split(r'/|\?', channel_link)[4]
                        youtube_user = re.split('\W', youtube_user)[0]
                        print("Youtube User", youtube_user)
                        youtube_channel_users[youtube_user] += 1

                    # Example: https://www.youtube.com/actdottv
                    elif (bool(re.match(r'https://www.youtube.com/[\w]+/?', channel_link))):
                        youtube_user = re.split(r'/|\?', channel_link)[3]
                        youtube_user = re.split('\W', youtube_user)[0]
                        print("Youtube User", youtube_user)
                        youtube_channel_users[youtube_user] += 1

        if(len(twitter_handle)) > 1:
            twitter_handle_list = sorted(list(twitter_handle.keys()), key=lambda x: twitter_handle[x], reverse=True)

            # lookup the user
            try:
                returned_users = api.lookup_users(screen_name=twitter_handle_list)
                for user in returned_users:

                    user_json = user._json
                    screen_name = user_json['screen_name'].lower()
                    print("Screen name: {} / website link: {}  ".format(screen_name, website_links))
                    if check_twitter_for_website_link(website_links, user_json):
                        selected_twitter_handle = screen_name
                        print("Selected twitter handle name: ", selected_twitter_handle)
                        break

            except:
                for twitter_handle in twitter_handle_list:
                    returned_user = api.lookup_users(screen_name = [twitter_handle])[0]

                    user_json = returned_user._json
                    screen_name = user_json['screen_name'].lower()

                    print("Screen name: {} / website link: {}  ".format(screen_name, website_links))           
                    if check_twitter_for_website_link(user_json, website_links):
                        selected_twitter_handle = screen_name
                        print("Selected twitter handle name: ", selected_twitter_handle)
                        break

        elif len(twitter_handle)==1:
            selected_twitter_handle = list(twitter_handle.keys())[0].lower()
            print("Twitter with only on handle: ", selected_twitter_handle)

        if selected_twitter_handle != '':
            num_twitter_handle += 1
            print("website domain name: ", tldextract.extract(get_domain(website_links)).domain)
            tw_similarity = SequenceMatcher(None, tldextract.extract(get_domain(website_links)).domain, selected_twitter_handle).ratio()

            new_channel_yt_twitter_sim.loc[index, "Twitter Handle"] = selected_twitter_handle
            new_channel_yt_twitter_sim.loc[index, "Twitter Similarity"] = tw_similarity
            
            # twitter handle to be reviewed
            twitter_handle_sim_score[selected_twitter_handle] = tw_similarity
            
            print("similarity: ", tw_similarity)
            selected_twitter_handle = ""

        # if we extracted more than one youtube id for a single new channel, we
        # need to select from one of them
        print("Youtube channel Id Dictionary", youtube_channel_id)
        headers= {"User-Agent": "Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"}

        select_youtube_id = ""
        if(len(youtube_channel_id) > 1):
            youtube_id_list = sorted(list(youtube_channel_id.keys()), key=lambda x: youtube_channel_id[x], reverse=True)
            print(youtube_id_list)
            for ids in youtube_id_list:
                print("Youtube Channel link : https://www.youtube.com/channel/{}/about".format(ids))
                yt_about_page = requests.get("https://www.youtube.com/channel/{}/about".format(ids), headers=headers)
                soup = BeautifulSoup(yt_about_page.content, features='html.parser')

                if check_youtube_for_website_link(soup, website_links, selected_twitter_handle):
                    select_youtube_id = ids
                    break
        elif len(youtube_channel_id) == 1:
            select_youtube_id = list(youtube_channel_id.keys())[0]
        print("selected youtube id: ", select_youtube_id)

        if select_youtube_id != "":
            new_channel_yt_twitter_sim.loc[index, "Youtube Channel"] = select_youtube_id
        
        # Test the above code and write code for select_youtube_user
        print("Youtube channel User Dictionary", youtube_channel_users)

        select_youtube_user = ""
        if (len(youtube_channel_users) > 1):
            youtube_user_list = sorted(list(youtube_channel_users.keys()), key=lambda x: youtube_channel_users[x], reverse=True)
            print(youtube_user_list)
            for users in youtube_user_list:
                print("Youtube Channel link : https://www.youtube.com/channel/{}/about".format(users))
                yt_about_page = requests.get("https://www.youtube.com/channel/{}/about".format(users), headers=headers)
                soup = BeautifulSoup(yt_about_page.content, features='html.parser')

                if check_youtube_for_website_link(soup, website_links, selected_twitter_handle):
                    select_youtube_user = users
                    break
        elif len(youtube_channel_users) == 1:
            select_youtube_user = list(youtube_channel_users.keys())[0]
        print("selected youtube user: ", select_youtube_user)

        if select_youtube_user != "":
            new_channel_yt_twitter_sim.loc[index, "Youtube Channel"] = select_youtube_user
        
        # statistics:
        if select_youtube_id != "" or select_youtube_user != "":
            num_youtube_channels += 1
        print("***************************************")
    except:
        num_fail_attempts += 1
        continue


for selected_twitter_handle, tw_similarity in twitter_handle_sim_score.items():           
    if isinstance(tw_similarity, float) and tw_similarity < 0.5:
        num_twitter_handle_to_review += 1
        print("Twitter handles to be reviewed: {} with Similarity: ".format(selected_twitter_handle, tw_similarity))

print("Number of twitter handle found/Number of total News channels : {} / {}".format(num_twitter_handle, num_channels))
print("Number of youtube user/id found/Number of total News channels : {} / {}".format(num_youtube_channels, num_channels))
print("Number of failed attempts/Total attempts or News channels : {} / {}".format(num_fail_attempts, num_channels))
print("Number of twitter to be reviewed: {}".format(num_twitter_handle_to_review))
# Out:
# idufghgf
# 0 : https://www.charlotteobserver.com
# Number of twitter handle found/Number of total News channels : 0 / 1
# Number of youtube user/id found/Number of total News channels : 0 / 1
# Number of failed attempts/Total attempts or News channels : 1 / 1
# Number of twitter to be reviewed: 0

# %%
twitter_handle
# Out:
# defaultdict(int,
#             {'accountable_us': 3,
#              'actdottv': 1,
#              'aldianews': 2,
#              'afjustice': 3,
#              'altnews': 2,
#              'AlterNet': 2,
#              'alternet': 1,
#              'AmandlaMedia': 7,
#              'SAHRCommission': 1,
#              'American_Bridge': 3,
#              'americansunited': 1,
#              'autostraddle': 2,
#              'BeingLiberal': 1,
#              'BillMoyers': 1,
#              'bitchmedia': 2,
#              'blkagendareport': 1,
#              'BJSocialNetwork': 2,
#              'frauenfelder': 1,
#              'pesco': 1,
#              'beschizza': 1,
#              'carla_sinclair': 1,
#              'jlw': 1,
#              'orenwolf': 1,
#              'BostonReview': 6,
#              'bust_magazine': 1,
#              'jegtheme': 1,
#              'CDN_Dimension': 1,
#              'capitalandmain': 3,
#              'Care2': 1,
#              'CeasefireMag': 1,
#              'amprog': 1,
#              'exposedbycmd': 1,
#              'c4ssdotorg': 1,
#              'ChangeGER': 1,
#              'Chicago_Reader': 2,
#              'ChicagoReporter': 3,
#              'ClimateHome': 2,
#              'codepink': 3,
#              'colorlines': 2,
#              'commune_mag': 1})

# %% [markdown]
# To get twitter handle, get several types of twitter links, thet are as follows:
# 1. https://twitter.com/accountable_us?ref_src=twsrc%5Etfw
# 2. https://twitter.com/accountable_us
# 3. https://twitter.com/@American_Bridge
# 4. https://twitter.com/intent/tweet?in_reply_to=1524776220386283522  ignore this one
# 5. https://twitter.com/intent/retweet?tweet_id=1524776220386283522  ignore this one
# 6. https://twitter.com/intent/like?tweet_id=1524776220386283522  ignore this one
# 7. https://twitter.com/search?q=%23EndTheBookFamine   ignore this one

# %% [markdown]
# To get youtube channel name, we got following links: <Br>
#     1. https://www.youtube.com/watch?v=QPgPteVrl3s - ignore this one <Br>
#     2. www.youtube.com/embed/m2LdbBgyOlQ - ignore this one <Br>
#     3. https://www.youtube.com/actdottv <Br>
#     4. https://www.youtube.com/user/pontealdiatv <Br>
#     5. https://www.youtube.com/user/blackamericaweb?sub_confirmation=1 <Br>
#     <Br>
#     6. https://www.youtube.com/channel/UCmX0gITcFMtmDSah8-wCChw/videos?view_as=subscriber <Br>
#     7. https://www.youtube.com/channel/UC_WSavcwZVE3ciFM8yCwkBw/ <Br>
#     8. https://www.youtube.com/channel/UCjfpIrbyc1hMT-CRZWbGF4g <Br>
#     9. https://www.youtube.com/c/AmericanBridgePAC <Br>
#     10. https://www.youtube.com/c/cosmopolitan?sub_confirmation=1 <Br>
#     11. https://www.youtube.com/channel/UCXu7fg-_KdAoHY7bmahr9vg/featured <Br>
#     12. https://www.youtube.com/channel/UCHdWMuH-IIveBWjIsOhK-dw/videos <Br>

# %%
# some original, 2.1 from ours.

# %%
channel_yt_twitter = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/2. scrap_youtube_twitter.csv")

# %%
update_twitter = channel_yt_twitter[channel_yt_twitter["Twitter Similarity"] < 0.5]

# %%
# santasurfing - account suspended
# 2885 ReedMCooper - accoutn suspended
update_twitter.loc[23, "Twitter Handle"] = ""
update_twitter.loc[29, "Twitter Handle"] = ""
update_twitter.loc[79, "Twitter Handle"] = "drudgeretort"
update_twitter.loc[93, "Twitter Handle"] = "FifthEstateMag"
update_twitter.loc[112, "Twitter Handle"] = "GQMagazine"
update_twitter.loc[120, "Twitter Handle"] = "HillReporter"
update_twitter.loc[161, "Twitter Handle"] = "modern_liberals"
update_twitter.loc[247, "Twitter Handle"] = "_UhuruNews_"
update_twitter.loc[257, "Twitter Handle"] = "DworkinReport"
update_twitter.loc[300, "Twitter Handle"] = "Upworthy"
update_twitter.loc[313, "Twitter Handle"] = "Wonkette"

update_twitter.loc[836, "Twitter Handle"] = "EverettHerald"
update_twitter.loc[1729, "Twitter Handle"] = "DailyO_"
update_twitter.loc[2494, "Twitter Handle"] = ""
update_twitter.loc[2564, "Twitter Handle"] = "fpmag"
update_twitter.loc[2867, "Twitter Handle"] = ""
update_twitter.loc[2885, "Twitter Handle"] = ""
update_twitter.loc[2887, "Twitter Handle"] = ""
# Out:
# C:\Users\wasil\Anaconda3\lib\site-packages\pandas\core\indexing.py:1817: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_column(loc, value, pi)

# %%
# 4th one from original, 3rd for ourself

# %%
channel_yt_twitter = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/2. scrap_youtube_twitter.csv")

# %%
channel_yt_twitter = channel_yt_twitter.reset_index()

# %%
update_csv = False

# statistics
num_requests_sent = 0
num_updates = 0
num_fail_attempts = 0

for index, row in channel_yt_twitter.iterrows():

    if pd.isna(channel_yt_twitter.iloc[index, 6]):
        channel_name = channel_yt_twitter.iloc[index, 1]
        website_links = channel_yt_twitter.iloc[index, 4]
        
        returned_users = api.search_users(channel_name, count = 10)
        num_requests_sent += 1
        update_csv = True
        
        for user in returned_users:
            user_json = user._json
            screen_name = user_json['screen_name'].lower()
            print("Screen name: {} / website link: {}  ".format(screen_name, website_links))
            
            if not pd.isna(website_links):
                if check_twitter_for_website_link(website_links, user_json):

                    selected_twitter_handle = screen_name
                    print("Selected twitter handle name: ", selected_twitter_handle)

                    tw_similarity = SequenceMatcher(None, tldextract.extract(get_domain(website_links)).domain, selected_twitter_handle).ratio()
                    print(tw_similarity)

                    channel_yt_twitter.iloc[index, 6] = selected_twitter_handle
                    channel_yt_twitter.iloc[index, 7] = tw_similarity
                    num_updates += 1
                    update_csv = False
                    break
        if update_csv == True:
            num_fail_attempts += 1
            update_csv = False
            
print("Number of successfull update {} / Number of requests sent: {}".format(num_updates, num_requests_sent))
print("Number of Failed update {} / Number of requests sent: {}".format(num_fail_attempts, num_requests_sent))
# Out:
# Screen name: aftonbladet / website link: https://www.aftonbladet.se
# checking ...
# True
# Selected twitter handle name:  aftonbladet
# 1.0
# Screen name: weareoversight / website link: https://www.americanoversight.org
# checking ...
# True
# Selected twitter handle name:  weareoversight
# 0.7096774193548387
# Screen name: blackamericaweb / website link: https://blackamericaweb.com/
# checking ...
# True
# Selected twitter handle name:  blackamericaweb
# 1.0
# Screen name: boingboing / website link: https://boingboing.net
# checking ...
# True
# Selected twitter handle name:  boingboing
# 1.0
# Screen name: ukchange / website link: https://www.change.org/
# checking ...
# True
# Selected twitter handle name:  ukchange
# 0.8571428571428571
# Screen name: chinaorgcn / website link: http://www.china.org.cn/
# checking ...
# True
# Selected twitter handle name:  chinaorgcn
# 0.6666666666666666
# Screen name: httpcnn / website link: https://www.cnn.com/
# checking ...
# False
# Screen name: blalkjalskdjfas / website link: https://www.cnn.com/
# checking ...
# False
# Screen name: comicsandsdaily / website link: https://www.comicsands.com
# checking ...
# True
# Selected twitter handle name:  comicsandsdaily
# 0.8
# Screen name: mpkebetter / website link: https://www.crikey.com.au/
# checking ...
# False
# Screen name: dailynewsbin / website link: http://www.dailynewsbin.com/
# checking ...
# False
# Screen name: binnector / website link: http://www.dailynewsbin.com/
# checking ...
# False
# Screen name: local4news / website link: https://www.metrotimes.com
# checking ...
# False
# Screen name: deadlinedetroit / website link: https://www.metrotimes.com
# checking ...
# False
# Screen name: metrodetroitn / website link: https://www.metrotimes.com
# checking ...
# False
# Screen name: detroitbiznews / website link: https://www.metrotimes.com
# checking ...
# False
# Screen name: greeningdet_com / website link: https://www.metrotimes.com
# checking ...
# False
# Screen name: crimeinthed / website link: https://www.metrotimes.com
# checking ...
# False
# Screen name: jghillfreep / website link: https://www.metrotimes.com
# checking ...
# False
# Screen name: mcmuckraker / website link: https://www.metrotimes.com
# checking ...
# True
# Selected twitter handle name:  mcmuckraker
# 0.2857142857142857
# Screen name: intifada / website link: https://electronicintifada.net/
# checking ...
# True
# Selected twitter handle name:  intifada
# 0.6153846153846154
# Screen name: elle_com / website link: nan
# Screen name: evrydayfeminism / website link: https://everydayfeminism.com/
# checking ...
# True
# Selected twitter handle name:  evrydayfeminism
# 0.967741935483871
# Screen name: joebiden_com / website link: nan
# Screen name: titlmagazine / website link: https://latest.com
# checking ...
# False
# Screen name: manutdlatestcom / website link: https://latest.com
# checking ...
# False
# Screen name: footballlatest / website link: https://latest.com
# checking ...
# False
# Screen name: latest_com / website link: https://latest.com
# checking ...
# True
# Selected twitter handle name:  latest_com
# 0.75
# Screen name: libcomorg / website link: http://libcom.org
# checking ...
# True
# Selected twitter handle name:  libcomorg
# 0.8
# Screen name: mashable / website link: https://mashable.com
# checking ...
# True
# Selected twitter handle name:  mashable
# 1.0
# Screen name: nymag / website link: http://nymag.com/
# checking ...
# True
# Selected twitter handle name:  nymag
# 1.0
# Screen name: nowtoronto / website link: https://nowtoronto.com/
# checking ...
# True
# Selected twitter handle name:  nowtoronto
# 1.0
# Screen name: opensociety / website link: https://www.opensocietyfoundations.org/
# checking ...
# True
# Selected twitter handle name:  opensociety
# 0.6666666666666666
# Screen name: outmagazine / website link: https://www.out.com
# checking ...
# False
# Screen name: rewirenewsgroup / website link: https://rewirenewsgroup.com/
# checking ...
# True
# Selected twitter handle name:  rewirenewsgroup
# 1.0
# Screen name: tpm / website link: https://talkingpointsmemo.com
# checking ...
# True
# Selected twitter handle name:  tpm
# 0.3
# Screen name: heerjeet / website link: https://www.thenation.com/
# checking ...
# True
# Selected twitter handle name:  heerjeet
# 0.35294117647058826
# Screen name: thegrio / website link: https://thegrio.com/
# checking ...
# True
# Selected twitter handle name:  thegrio
# 1.0
# Screen name: atlblog / website link: https://abovethelaw.com/
# checking ...
# True
# Selected twitter handle name:  atlblog
# 0.3333333333333333
# Screen name: bygeorgethomas / website link: https://www.beaconjournal.com/
# checking ...
# True
# Selected twitter handle name:  bygeorgethomas
# 0.2222222222222222
# Screen name: www_aol_com / website link: https://www.aol.com/
# checking ...
# False
# Screen name: applenews / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: applenewsuk / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: iphone_news / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: applenws / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: appleinsider / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: techapplenews / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: applestreem / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: appleterminal / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: theapplehub / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: aaplstocknews / website link: https://www.apple.com/apple-news/
# checking ...
# False
# Screen name: aptnnews / website link: https://www.aptnnews.ca/
# checking ...
# True
# Selected twitter handle name:  aptnnews
# 1.0
# Screen name: tucsonstar / website link: http://tucson.com/
# checking ...
# False
# Screen name: dwichner / website link: http://tucson.com/
# checking ...
# True
# Selected twitter handle name:  dwichner
# 0.2857142857142857
# Screen name: arteen / website link: https://www.arte.tv/
# checking ...
# True
# Selected twitter handle name:  arteen
# 0.8
# Screen name: asiasentinel / website link: https://www.asiasentinel.com/
# checking ...
# True
# Selected twitter handle name:  asiasentinel
# 1.0
# Screen name: onlineathens / website link: https://www.onlineathens.com/
# checking ...
# True
# Selected twitter handle name:  onlineathens
# 1.0
# Screen name: theavclub / website link: nan
# Screen name: backchnnl / website link: nan
# Screen name: balkaninsight / website link: nan
# Screen name: bostondotcom / website link: https://www.boston.com/
# checking ...
# True
# Selected twitter handle name:  bostondotcom
# 0.6666666666666666
# Number of successfull update 28 / Number of requests sent: 195
# Number of Failed update 167 / Number of requests sent: 195

# %%
channel_yt_twitter = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/3. scrap_youtube_twitter_handle.csv")

# %%
# 5 form the original and 4th for ours.

# %%
channel_yt_twitter = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/3. scrap_youtube_twitter_handle.csv")
channel_yt_twitter.drop("index",axis=1,inplace=True)

# %%
def youtube_search_bar(channel_name):
    r = "https://www.youtube.com/results?search_query={}".format(channel_name)
    return r

# %%
for index, row in channel_yt_twitter.iterrows():
    
    
    num_search_results = 0
    
    # if we dont have channel name or its user id
    if pd.isna(channel_yt_twitter.iloc[index, 4]):
        print("*********************")
        print("Channel name: ", channel_yt_twitter.iloc[index, 0])
        for _ in range(5):
            if num_search_results == 0:
                result_link = youtube_search_bar(channel_yt_twitter.iloc[index, 0])
                try:
                    response = requests.get(result_link, headers = headers)
                except:
                    response = requests.get(result_link)
                time.sleep(1)

                if response.text:
                    soup = BeautifulSoup(response.text, 'lxml')

                    #print(soup)

                    aid = soup.find('script',string=re.compile('ytInitialData')).text
                    yt_about_page = json.loads(aid[20:-1])
                    
                    #pp.pprint(yt_about_page)

                    result_lists = yt_about_page["contents"]["twoColumnSearchResultsRenderer"]["primaryContents"] \
                       ["sectionListRenderer"]["contents"][0]["itemSectionRenderer"]["contents"]

                    #result_list = recursive_lookup("channelRenderer", yt_about_page)
                    list_of_retrieved_channel_json = []
                    for r in result_lists:
                        
                        if list(r.keys())[0] == "channelRenderer":
                            print("channel result found on the seach result")
                            list_of_retrieved_channel_json.append(r)
                            num_search_results = len(list_of_retrieved_channel_json)
# Out:
# *********************
# Channel name:  Accountable.US
# channel result found on the seach result
# *********************
# Channel name:  Aftonbladet
# channel result found on the seach result
# *********************
# Channel name:  Alternet (www.alternet.org)
# channel result found on the seach result
# channel result found on the seach result
# *********************
# Channel name:  America Blog (americablog.com)
# *********************
# Channel name:  American Oversight
# *********************
# Channel name:  Americans United for Separation of Church and State (www.au.org)
# *********************
# Channel name:  Angry White Men (angrywhitemen.org)
# *********************
# Channel name:  Attack the System (attackthesystem.com)
# channel result found on the seach result
# *********************
# Channel name:  AutoStraddle (www.autostraddle.com)
# channel result found on the seach result
# *********************
# Channel name:  Baltimore City Paper (www.citypaper.com)
# channel result found on the seach result
# *********************
# Channel name:  Being Liberal (www.themaven.net)
# *********************
# Channel name:  BillMoyers.com (billmoyers.com)
#
# *********************
# Channel name:  Bitch Media (bitchmedia.org)
# channel result found on the seach result
# *********************
# Channel name:  Black Agenda Report (blackagendareport.com)
# *********************
# Channel name:  Black Lives Matter (blacklivesmatter.com)
# *********************
# Channel name:  Black Main Street (blackmainstreet.net)
# *********************
# Channel name:  BoingBoing (boingboing.net)
# *********************
# Channel name:  Boston Review (bostonreview.net)
# channel result found on the seach result
# *********************
# Channel name:  Bust Magazine (bust.com)
# *********************
# Channel name:  Call to Activism (calltoactivism.com)
# *********************
# Channel name:  Canada Fact Check (canadafactcheck.ca)
# *********************
# Channel name:  Care2 (www.care2.com)
# *********************
# Channel name:  Ceasefire Magazine (ceasefiremagazine.co.uk)
# channel result found on the seach result
# *********************
# Channel name:  Center for Media and Democracy (www.prwatch.org)
# channel result found on the seach result
# *********************
# Channel name:  Change.org (https://www.change.org/)
# channel result found on the seach result
# *********************
# Channel name:  Chicago Reader (www.chicagoreader.com)
# channel result found on the seach result
# *********************
# Channel name:  China Internet Information Center (china.org.cn)
# *********************
# Channel name:  Citizen Critics (citizencritics.org)
# *********************
# Channel name:  Climate Home News (climatechangenews.com)
# *********************
# Channel name:  CNN (www.cnn.com)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14020/1874211008.py in <module>
#      15                 except:
#      16                     response = requests.get(result_link)
# ---> 17                 time.sleep(1)
#      18
#      19                 if response.text:
#
# KeyboardInterrupt:

# %%
website_name = "Climate Home News (climatechangenews.com)"

def get_website_name(website_name):
    if "(" in website_name:
        print(website_name)
        print(website_name.split("(", 1))
        splitted_list = website_name.split("(", 1)
        for sl in splitted_list:
            if (")" not in sl) and ("(" not in sl):
                if ".com" not in sl:
                    print(sl.strip())
                    return sl.strip()

# %%
for index, row in channel_yt_twitter.iterrows():
    
    num_search_results = 0
    
    # if we dont have channel name or its user id
    if pd.isna(channel_yt_twitter.iloc[index, 4]):
        print("*********************")
        print("Channel name: ", channel_yt_twitter.iloc[index, 0])
        for _ in range(5):
            if num_search_results == 0:
                result_link = youtube_search_bar(channel_yt_twitter.iloc[index, 0])
                try:
                    response = requests.get(result_link, headers = headers)
                except:
                    response = requests.get(result_link)
                time.sleep(1)

                if response.text:
                    soup = BeautifulSoup(response.text, 'lxml')

                    #print(soup)

                    aid = soup.find('script',string=re.compile('ytInitialData')).text
                    yt_about_page = json.loads(aid[20:-1])
                    
                    #pp.pprint(yt_about_page)

                    result_lists = yt_about_page["contents"]["twoColumnSearchResultsRenderer"]["primaryContents"] \
                       ["sectionListRenderer"]["contents"][0]["itemSectionRenderer"]["contents"]

                    #result_list = recursive_lookup("channelRenderer", yt_about_page)
                    list_of_retrieved_channel_json = []
                    for r in result_lists:
                        
                        if list(r.keys())[0] == "channelRenderer":
                            print("channel result found on the seach result")
                            list_of_retrieved_channel_json.append(r)
                            num_search_results = len(list_of_retrieved_channel_json)
        
        
        for channel_json in list_of_retrieved_channel_json:    
            channel_id = channel_json["channelRenderer"]["channelId"]
            channel_title = channel_json["channelRenderer"]["title"]["simpleText"]
            print(channel_id, channel_title)
            
            # check if we got the right youtube channel or not.
            # we can compare it with the domain of the website and twitter handle.
            header = {"User-Agent": "Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"}
            if channel_title != "":
                about_page = "https://www.youtube.com/channel/{}/about".format(channel_id)
                yt_about_page = requests.get(about_page, headers=header)
                time.sleep(1)
                soup = BeautifulSoup(yt_about_page.content, features='html.parser')
                
                if check_youtube_for_website_link(soup, channel_yt_twitter.iloc[index, 3], channel_yt_twitter.iloc[index, 5]):
                    print("match found!")
                    # update the csv file.
                    channel_yt_twitter.iloc[index, 4] = channel_title
# Out:
# *********************
# Channel name:  Accountable.US
# channel result found on the seach result
# UCRvUQd-GsCR97qKReTE89jQ Accountable US
# match found!
# *********************
# Channel name:  Aftonbladet
# channel result found on the seach result
# UC7QxZdogxV1gloaOBO02wiw Aftonbladet
# match found!
# *********************
# Channel name:  Alternet (www.alternet.org)
# channel result found on the seach result
# channel result found on the seach result
# channel result found on the seach result
# UCByDWB-GsSjHnUS5o7Hohsg AlterNet
# UC0iBEcQdEurbfEXAtPrF2Vw Viral Alternet
# UCLxRAQpUVzC_wFzaT1hpDRg AlterNET Deluxe
# *********************
# Channel name:  America Blog (americablog.com)
# *********************
# Channel name:  American Oversight
# *********************
# Channel name:  Americans United for Separation of Church and State (www.au.org)
# *********************
# Channel name:  Angry White Men (angrywhitemen.org)
# *********************
# Channel name:  Attack the System (attackthesystem.com)
# channel result found on the seach result
# UCvPGyiUAUP8-4Z4jJh16Xxg System Attack
# *********************
# Channel name:  AutoStraddle (www.autostraddle.com)
# channel result found on the seach result
# UCxkR6LOu5QV7Ua9-UJIKBBg Autostraddle Dotcom
# *********************
# Channel name:  Baltimore City Paper (www.citypaper.com)
# channel result found on the seach result
# UCOnZ7LmieYKwoDYZwRL76xA CityPaper
# *********************
# Channel name:  Being Liberal (www.themaven.net)
# *********************
# Channel name:  BillMoyers.com (billmoyers.com)
#
# *********************
# Channel name:  Bitch Media (bitchmedia.org)
# channel result found on the seach result
# UCFdJR3ZSJcZ7RGWdSYHt4ag BitchMedia
# match found!
# *********************
# Channel name:  Black Agenda Report (blackagendareport.com)
# *********************
# Channel name:  Black Lives Matter (blacklivesmatter.com)
# *********************
# Channel name:  Black Main Street (blackmainstreet.net)
# *********************
# Channel name:  BoingBoing (boingboing.net)
# *********************
# Channel name:  Boston Review (bostonreview.net)
# channel result found on the seach result
# UCEOtO8PPWXpCQmX1QpTx3EQ Boston Review
# match found!
# *********************
# Channel name:  Bust Magazine (bust.com)
# *********************
# Channel name:  Call to Activism (calltoactivism.com)
# *********************
# Channel name:  Canada Fact Check (canadafactcheck.ca)
# *********************
# Channel name:  Care2 (www.care2.com)
# *********************
# Channel name:  Ceasefire Magazine (ceasefiremagazine.co.uk)
# channel result found on the seach result
# UC4XfPcG6Y4LozfHgzGu2XwA Ceasefire Magazine
# match found!
# *********************
# Channel name:  Center for Media and Democracy (www.prwatch.org)
# channel result found on the seach result
# UC3Qs31jxhhi0tOMhSEpe3WQ The Center for Media and Democracy
# match found!
# *********************
# Channel name:  Change.org (https://www.change.org/)
# channel result found on the seach result
# UCcrxX7CwpZjNgnSRF7vbWlA Change.org Deutschland
# match found!
# *********************
# Channel name:  Chicago Reader (www.chicagoreader.com)
# channel result found on the seach result
# UCSAEKsuh_gwX_MmpRjLhdMw Chicago Reader
# match found!
# *********************
# Channel name:  China Internet Information Center (china.org.cn)
# *********************
# Channel name:  Citizen Critics (citizencritics.org)
# *********************
# Channel name:  Climate Home News (climatechangenews.com)
# channel result found on the seach result
# UC-JlxQDZn5hLzhGSbtSJjzw Climate Home News
# *********************
# Channel name:  CNN (www.cnn.com)
# channel result found on the seach result
# UCupvZG-5ko_eiXAupbDfxWw CNN
# match found!
# *********************
# Channel name:  Code Pink (www.codepink.org)
# *********************
# Channel name:  Columbus Free Press (https://columbusfreepress.com/)
# *********************
# Channel name:  Comic Sands
# channel result found on the seach result
# channel result found on the seach result
# UCpNh06Qz_2PRJUxJS71Wn_w Sans Comic TV
# UCvErQSdzdmT6-w6cFtsKA9A Comic Sands
# *********************
# Channel name:  Common Dreams (www.commondreams.org)
# *********************
# Channel name:  Commune Magazine (communemag.com)
# channel result found on the seach result
# channel result found on the seach result
# channel result found on the seach result
# UCfkutiMDxBHCgmxgTFh30pA Commune Mag
# UClOykAh_y3V8wvOYbZtPqgA Comacon Magazine
# UCq0de4PFzcGhjNHWc2g97DQ NOTRE COMMUNE MAG ET TV
# *********************
# Channel name:  Cop Block (copblock.org)
# channel result found on the seach result
# UCl-qkifCsEcn0AuTSRiZ0Lw Cop Block
# match found!
# *********************
# Channel name:  CounterPunch (www.counterpunch.org)
# channel result found on the seach result
# UCaXfI2HoM6JuZ3v6pk4R5wA Counterpunch With Trevor Loudon
# *********************
# Channel name:  CrimethInc (crimethinc.com)
# channel result found on the seach result
# UCH9VbQUhFVjTyUZhZqDVlDw CrimethInc. Ex-Workers Collective
# *********************
# Channel name:  Crooks and Liars (crooksandliars.com)
# *********************
# Channel name:  Current Affairs (www.currentaffairs.org)
# *********************
# Channel name:  Curve Magazine (www.curvemag.com)
# channel result found on the seach result
# UC5SfJd4eEr7e3S2WfhtWfIw Curves Magazin
# *********************
# Channel name:  Daily Beast (www.thedailybeast.com)
# channel result found on the seach result
# UC7qZ_e097NBkgOljy1joVRA The Daily Beast
# match found!
# *********************
# Channel name:  Daily Dot (www.dailydot.com)
# *********************
# Channel name:  Daily Kos
# channel result found on the seach result
# UC1Z1i5ClfrJhyu9z1hlmDkQ Daily Kos
# match found!
# *********************
# Channel name:  Daily News bin
# *********************
# Channel name:  Daily Record (Scotland) (www.dailyrecord.co.uk)
# channel result found on the seach result
# UC6B3kmCZJc7YMG-948t6M7w Daily Record
# match found!
# *********************
# Channel name:  Daily Sound and Fury (dailysoundandfury.com)
# channel result found on the seach result
# UCxhCE4DmIkQSK14NWEHk72A Daily Sound & Fury
# *********************
# Channel name:  DeadState (deadstate.org)
# *********************
# Channel name:  Deep South Voice (deepsouthvoice.com)
# channel result found on the seach result
# channel result found on the seach result
# UCA-qJxAjhq1G6aDsTHuPWug Deep South Voice
# match found!
# UCp5XZrIMCOCpciazknNn4Mg Deep Voice Audiobooks
# *********************
# Channel name:  Democracy Chronicles (democracychronicles.org)
# *********************
# Channel name:  Democracy Guardian
# *********************
# Channel name:  Democracy Journal (democracyjournal.org)
# *********************
# Channel name:  Democracy Now (www.democracynow.org)
# channel result found on the seach result
# UCzuqE7-t13O4NIDYJfakrhw Democracy Now!
# match found!
# *********************
# Channel name:  Democratic Underground (www.democraticunderground.com)
# *********************
# Channel name:  Deshabhimani (https://www.deshabhimani.com/)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14020/4083673484.py in <module>
#      14                 except:
#      15                     response = requests.get(result_link)
# ---> 16                 time.sleep(1)
#      17
#      18                 if response.text:
#
# KeyboardInterrupt:

# %%
l = []
for _ in range(5):
    l = list((1, 2, 3))

# %%
# Out:
# [1, 2, 3]

# %%
def recursive_lookup(k, d):
    # imporvised from https://stackoverflow.com/questions/48314755/find-keys-in-nested-dictionary
    # here, k is the key to search
    # d is the dictonary to find from.
    if k in d: return d[k]
    for v in d.values():
        if isinstance(v, dict):
            a = recursive_lookup(k, v)
            if a is not None: yield a
        elif isinstance(v, list):
            for v_list in v:
                if isinstance(v_list, dict):
                    b = recursive_lookup(k, v_list)
                    if b is not None: yield b
    return None
#recursive_lookup("description", yt_about_page)

# %%
def search_dict(partial, key):
    if isinstance(partial, dict):
        for k, v in partial.items():
            if k == key:
                yield v
            else:
                for o in search_dict(v, key):
                    yield o
    elif isinstance(partial, list):
        for i in partial:
            for o in search_dict(i, key):
                yield o

# %%
# 6 from the original, 5th from our

# %%
def get_youtube_channel_id(service, part_id, youtube_user):
    """
    Get youtube channel id with the given youtube user.
    """
    for i in range(3):
        try:
            response = service.channels().list(part = part_id, forUsername=youtube_user)
            response = response.execute()
            #print(response)
            # if there is a response
            if response is not None:
                if "items" in response:
                    if isinstance(response["items"], list):
                        if len(response["items"][0]) > 0:
                            #print("yes")
                            #print(response["items"][0]["id"])
                            channel_id = response["items"][0]["id"]
                            return channel_id
            else:
                return ""

        except:
            time.sleep(2**i)
            print("exception!")
    return ""

# %%
get_youtube_channel_id(youtube_service, "id", "sentdex")
# Out:
# 'UCfzlCWGWYyIQ0aLC5w48gBQ'

# %%
def check_youtube_channel_id(service, part_id, youtube_id):
    """
    Get youtube channel id with the given youtube user.
    """
    for i in range(3):
        try:
            response = service.channels().list(part = part_id, id=youtube_id)
            response = response.execute()
            #print(response)
            # if there is a response
            if response is not None:
                if "items" in response:
                    if isinstance(response["items"], list):
                        if len(response["items"][0]) > 0:
                            #print("yes")
                            #print(response["items"][0]["id"])
                            channel_id = response["items"][0]["id"]
                            return channel_id
            else:
                return ""
        except:
            time.sleep(2**i)
            print("exception!")
    return ""

# %%
check_youtube_channel_id(youtube_service, "id", 'UCfzlCWGWYyIQ0aLC5w48gBQ')
# Out:
# 'UCfzlCWGWYyIQ0aLC5w48gBQ'

# %%
# for simplicity, for now, we will use csv 3, although it should have been csv 5.
channel_yt_twitter = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/3. scrap_youtube_twitter_handle.csv")
channel_yt_twitter.drop("index",axis=1,inplace=True)
channel_yt_twitter['Youtube User'] = channel_yt_twitter['Youtube Channel']

# %%
# iterate over the dataframe
for index, row in channel_yt_twitter.iterrows():
    
    channel_id_user = channel_yt_twitter.iloc[index, 4]
    
    if not pd.isna(channel_id_user):
        
        # first, we will call get_youtube_channel_id().
        channel_id_response = get_youtube_channel_id(youtube_service, part, channel_id_user)
        print(channel_id_response)

        if channel_id_response == "":
            print("Cannot find from the first function, trying again from the second function!!!")
            channel_id_response = check_youtube_channel_id(youtube_service, part, channel_id_user)
            print(channel_id_response)
            if channel_id_response == "":
                print("Cannot find from the second function!!!")
            else:
                channel_yt_twitter.iloc[index, 4] = channel_id_response
        else:
            channel_yt_twitter.iloc[index, 4] = channel_id_response
# Out:
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
# UCGrUeq1FtRamLqZgaCIgB3w
# UC4chaUevLgCVSz-RcgqgoZQ
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UCmX0gITcFMtmDSah8-wCChw
# UCsSSZZIwlM9OajvbRSydK2A
#
# Cannot find from the first function, trying again from the second function!!!
# UC_WSavcwZVE3ciFM8yCwkBw
# UCexetvuR0DbNlprwhe4Ze1g
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UCXu7fg-_KdAoHY7bmahr9vg
#
# Cannot find from the first function, trying again from the second function!!!
# UCjfpIrbyc1hMT-CRZWbGF4g
# UC0COu43Li7CUL2jseBpH9kQ
# UCOA38--mWqKKdCAr6eFy-sA
# UCKL_VqV2UqBnmjGy4fLQ24g
#
# Cannot find from the first function, trying again from the second function!!!
# UCHdWMuH-IIveBWjIsOhK-dw
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
# UCrXmzxXsc8I0jIBWc51ti2g
#
# Cannot find from the first function, trying again from the second function!!!
# UC4ZxKhcNYIm4ngklkG-ki0A
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UCzLKquBnVnmwE8LBYSQTK3w
#
# Cannot find from the first function, trying again from the second function!!!
# UCFsh2bHIGqgRVZnZX8xhI0Q
# UC27KdqL8GCxqXgurmGpkb7g
# UC-3jIAlnQmbbVMV6gR7K8aQ
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UCef5LW_IXrGLIUiTQSCv6VA
#
# Cannot find from the first function, trying again from the second function!!!
# UCOCmlobISshBIjiNVVQUI1Q
#
# Cannot find from the first function, trying again from the second function!!!
# UCLiVYX4--R2vM5KLGK2S2WA
# UCF84AcvzViybFvmNsiA_gIw
#
# Cannot find from the first function, trying again from the second function!!!
# UCxFmw3IUMDUC1Hh7qDjtjZQ
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
# UCeHHAF22PljrnnjskZeljmg
#
# Cannot find from the first function, trying again from the second function!!!
# UCjfFAxLaJ_oGCjrFSGWI9vg
#
# Cannot find from the first function, trying again from the second function!!!
# UCOzT3fyPN7uTGUIha0YIl_g
#
# Cannot find from the first function, trying again from the second function!!!
# UCFQ7vc-dWlSUZd6OqsAepMA
# UCrCCWFYT1iL_dkJW-c7xDfA
#
# Cannot find from the first function, trying again from the second function!!!
# UCI4iIRZltBUQITyvCXz_PZg
# UCRG85wzvd1a9RJhbhwkGKeA
#
# Cannot find from the first function, trying again from the second function!!!
# UC5zPi7g6wk5Y8fiPBhtvL-w
#
# Cannot find from the first function, trying again from the second function!!!
# UC_70iWZ6ym2cglS_kv5YfmA
#
# Cannot find from the first function, trying again from the second function!!!
# UC9r9HYFxEQOBXSopFS61ZWg
# UCb0loaR9alFkLWjdMSTN9uw
# UCjIwnDSmohltS_z8YCuZUHg
# UCNia_X3a7HLxBSN-z57UGQw
# UCMou8jEaN0213UcOS2-yuFw
# UCsD-Qms-AkXDrsU962OicLw
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UCn7b6PCehgg4ZNh5NDcmy9g
# UCGbQJy-531_5vfphay-rChQ
#
# Cannot find from the first function, trying again from the second function!!!
# UCQLRK5wiWGmzp4dnFt0arwA
#
# Cannot find from the first function, trying again from the second function!!!
# UCSxCtu4groYcYi_2rk5-xdg
# UCJoF7fHbtskvHH-fJUBRddQ
#
# Cannot find from the first function, trying again from the second function!!!
# UCt6tgXcL1hC9gItUIgiDvMQ
# UCQtQBtdJBBvCCtK1AS_ZcDA
# UCrmm_7RDZJeQzq2-wvmjueg
# UCsZsDjpf2Ppv_cT2K6_q2cw
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
# UCYWIEbibRcZav6xMLo9qWWw
#
# Cannot find from the first function, trying again from the second function!!!
# UC-JblcinswY50lrUdSaRNEg
# UCZhCc712aJSFGSRLzyakpLA
# UC0IXvMUUPeYNVGe88ieMDEg
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UC4cCsgbPuRZG6LvRmCPjXgg
# UCLjzzg-cFWpEEjnWCOpXp3Q
# UCXnaN9lkmZJ2IaDYPy-rhlQ
#
# Cannot find from the first function, trying again from the second function!!!
# UC9-EHjkOfBwD2_jVBsgpxqQ
# UC8Xr-juneTgA76lIbBlMYPw
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
# UC9p4VHaB7JWTZgvVwMMWF3Q
#
# Cannot find from the first function, trying again from the second function!!!
# UC2J3olQxMEQLEmpzisRVzpg
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UCg5bOg1qVoZ2JDJ7MmjY63A
# UCYpycoDf__f6HE4Ero9zCNw
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UC7pjcXDOGZ9uJlTJ8dIet5g
#
# Cannot find from the first function, trying again from the second function!!!
# UCeHbMlHDec5NmJfiQXMYGXQ
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
# UCswDowOOvJ-fkCgH9YAITjQ
# UCIsbLox_y9dCIMLd8tdC6qg
# UCr7veYVN9t6UPoB1_icFG1g
# UCwQKTzuzDIazT37whnR0lqQ
# UCQcPBLsq9rRc5TxDqSz_Dog
# UCzfnLtFa4Oi7y3tOqN5jFSA
# UCYxRlFDqcWM4y7FfpiAN3KQ
# UCBi2mrWuNuyYy4gbM6fU18Q
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
# UCNye-wNBqNL5ZzHSJj3l8Bg
# UCYC5hBwBcQ1WGJ0pFeMJBUQ
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
# UCfVotMGyD7sVMomr2AzsBtQ
# UCeLoup1A6odH6fp_4pj1sCQ
# UC52X5wxOL_s5yw0dQk7NtgA
# UCK0z0_5uL7mb9IjntOKi5XQ
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!
#
# Cannot find from the first function, trying again from the second function!!!
# UCvL92VdN1kAeX_769U407Nw
#
# Cannot find from the first function, trying again from the second function!!!
# UCOK_An4e3Um5pkziO3e1Qyw
# UCIbFhmYOqhvrudtVZG5-KEA
#
# Cannot find from the first function, trying again from the second function!!!
# UCS5gJZ-_6k3e26hG7H4t3vA
# UCcNkGwVX4_F1rcgItwCk1zQ
# UCcyq283he07B7_KUX07mmtA
#
# Cannot find from the first function, trying again from the second function!!!
#
# Cannot find from the second function!!!

# %%
channel_yt_twitter = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/5. scrap_youtube_ids.csv")

# %%
"Title, Category,Img,Country,URL,Domain,OrigURL,TWHandle,TWSim,YTId,YTUser".rstrip().split(',')[-1]
# Out:
# 'Title, Category,Img,Country,URL,Domain,OrigURL,TWHandle,TWSim,YTId,YTUser'

# %%
playlist_id = "UU" + "Accountable US"
https://www.youtube.com/playlist?list=UUAccountable US

# %%
response = youtube_service.channels().list(part = "id", forUsername="actdottv")
response = response.execute()
response
# Out:
# {'kind': 'youtube#channelListResponse',
#  'etag': 'RuuXzTIr0OoDqI4S0RU6n4FqKEM',
#  'pageInfo': {'totalResults': 0, 'resultsPerPage': 5}}

# %%
# 5.1 script

# %%
channel_id = requests.get('https://www.googleapis.com/youtube/v3/search?part=id&q={}&type=channel&key={}'.format(channel_username, cfg["YOUTUBE_KEY"])).json()#['items'][0]['id']['channelId']

# %%
for index, row in channel_yt_twitter.iterrows():
    channel_username = channel_yt_twitter.loc[index, "Youtube Channel"]
    if not pd.isna(channel_username):
        #channel_username = "National Youth Rights Association"
        channel_id = requests.get('https://www.googleapis.com/youtube/v3/search?part=id&q={}&type=channel&key={}'.format(channel_username, cfg["YOUTUBE_KEY"])).json()

        yt_similarity_dict = defaultdict()

        if "items" in channel_id:
            print(len(channel_id["items"]))

            if isinstance(channel_id["items"], list):
                for item in channel_id["items"]:
                    if "id" in item:
                        if "channelId" in item["id"]:
                            id_ = item["id"]["channelId"]
                            yt_similarity_score = yt_similarity(id_)
                            yt_similarity_dict[id_] = yt_similarity_score
                if len(yt_similarity_dict) > 0:
                    print(channel_username, " - ", list(yt_similarity_dict.keys())[0])
                    
                    # update the csv file
                    channel_yt_twitter.loc[index, "Youtube Channel"] = list(yt_similarity_dict.keys())[0]
# Out:
# 5
# ---------------------------------------------------------------------------
# HttpError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14440/3076612330.py in <module>
#      17                             #print(item["id"]["channelId"])
#      18                             id_ = item["id"]["channelId"]
# ---> 19                             yt_similarity_score = yt_similarity(id_)
#      20                             yt_similarity_dict[id_] = yt_similarity_score
#      21                 if len(yt_similarity_dict) > 0:
#
# ~\AppData\Local\Temp/ipykernel_14440/4279847225.py in yt_similarity(id)
#       1 def yt_similarity(id):
#       2     response = youtube_service.channels().list(part = "brandingSettings, contentDetails, contentOwnerDetails, id ,localizations ,snippet, statistics, status, topicDetails", id=id)
# ----> 3     response = response.execute()
#       4
#       5     selected_youtube_channel = ""
#
# ~\Anaconda3\lib\site-packages\googleapiclient\_helpers.py in positional_wrapper(*args, **kwargs)
#     128                 elif positional_parameters_enforcement == POSITIONAL_WARNING:
#     129                     logger.warning(message)
# --> 130             return wrapped(*args, **kwargs)
#     131
#     132         return positional_wrapper
#
# ~\Anaconda3\lib\site-packages\googleapiclient\http.py in execute(self, http, num_retries)
#     936             callback(resp)
#     937         if resp.status >= 300:
# --> 938             raise HttpError(resp, content, uri=self.uri)
#     939         return self.postproc(resp, content)
#     940
#
# HttpError: <HttpError 403 when requesting https://youtube.googleapis.com/youtube/v3/channels?part=brandingSettings%2C+contentDetails%2C+contentOwnerDetails%2C+id+%2Clocalizations+%2Csnippet%2C+statistics%2C+status%2C+topicDetails&id=UC2rcCFQBotDt0iKsOliayhg&key=AIzaSyA8s5I13mRliRdxWtiqIxbU-Y_noMjsd6o&alt=json returned "The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.". Details: "[{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]">

# %%
channel_username = "actdottv"
channel_id = requests.get('https://www.googleapis.com/youtube/v3/search?part=id&q={}&type=channel&key={}'.format(channel_username, cfg["YOUTUBE_KEY"])).json()

yt_channel_id = []
#yt_similarity_dict = defaultdict()
print(channel_id)
if "items" in channel_id:
    print(len(channel_id["items"]))

    for item in channel_id["items"]:
        if "id" in item:
            if "channelId" in item["id"]:
                id_ = item["id"]["channelId"]
                yt_channel_id.append(id_)
    if len(yt_channel_id) > 0:
        print(channel_username, " - ", yt_channel_id[0])

        # update the csv file
        #channel_yt_twitter.loc[index, "Youtube Channel"] = yt_channel_id[0]
# Out:
# {'error': {'code': 403, 'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'errors': [{'message': 'The request cannot be completed because you have exceeded your <a href="/youtube/v3/getting-started#quota">quota</a>.', 'domain': 'youtube.quota', 'reason': 'quotaExceeded'}]}}

# %%
    def yt_similarity(id):
        response = youtube_service.channels().list(part = "brandingSettings, contentDetails, contentOwnerDetails, id ,localizations ,snippet, statistics, status, topicDetails", id=id)
        response = response.execute()

        selected_youtube_channel = ""
        if "items" in response:
            for item in response["items"]:
                if "snippet" in item:
                    if "title" in item["snippet"]:
                        selected_youtube_channel = item["snippet"]["title"]
                    elif "localized" in item["snippet"]:
                        if "title" in item["snippet"]["localized"]:
                            selected_youtube_channel = item["snippet"]["localized"]["title"]
                elif "brandingSettings" in item:
                    if "channel" in item["brandingSettings"]:
                        if "title" in item["brandingSettings"]["channel"]:
                            selected_youtube_channel = item["brandingSettings"]["channel"]["title"]

        if selected_youtube_channel != "":
            yt_similarity = SequenceMatcher(None, channel_yt_twitter.loc[0, "Name"], selected_youtube_channel).ratio()
            return yt_similarity
        return 0

# %%
from difflib import SequenceMatcher
SequenceMatcher(None, channel_yt_twitter.loc[0, "Name"], "Accountable US").ratio()
# Out:
# 0.9285714285714286

# %%
tldextract.extract(get_domain(channel_yt_twitter.loc[0, "Website"])).domain
# Out:
# 'accountable'

# %%
# 5.2 sxript

# %%
channel_yt_twitter = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/5.1 get_yt_ids.csv")

# %%
#channel_yt_twitter[1659, "Youtube Channel"] = "UCBHaevn-06RSuh3k9LkA2BA"
#channel_yt_twitter[225, "Youtube Channel"] = "UCNXbjiFnvhmGEnI97MYESWQ"
#channel_yt_twitter[235, "Youtube Channel"] = "UCJqloayL-p1TP4Ed_fr53CA"

channel_yt_twitter[218, "Youtube Channel"] = "UCYWIEbibRcZav6xMLo9qWWw"
channel_yt_twitter[2271, "Youtube Channel"] = "UC1PRGaduTPEkvzBYAthpkhQ"
channel_yt_twitter[2205, "Youtube Channel"] = "UCun4tg1BecN4PuxwZ6mL3NA"
channel_yt_twitter[2231, "Youtube Channel"] = "UCKV_ACaioUGSz0pyg07Zekg"
channel_yt_twitter[2237, "Youtube Channel"] = "UCkJ1N-7g9Q6n7KnriGit-Ig"
channel_yt_twitter[2251, "Youtube Channel"] = "UCE1KT9DTZCQtf3PmAmWwOIA"
channel_yt_twitter[2275, "Youtube Channel"] = "UCWE58e_BbmBgE8h-oskutQA"
channel_yt_twitter[2568, "Youtube Channel"] = "UCiRXT7Ib7A8VkoJNjfYTctQ"
channel_yt_twitter[2994, "Youtube Channel"] = "UCgZeFXOjOCNq7QMgTEKNgJQ"
channel_yt_twitter[3028, "Youtube Channel"] = "UC9gm0OdmoAkGxIZG8veaxnw"

channel_yt_twitter[2994, "Youtube Channel"] = "UC9gm0OdmoAkGxIZG8veaxnw"

# UCIbFhmYOqhvrudtVZG5-KEA  -  UCEeLgkduIxQthKGHKSXL32A
channel_yt_twitter[395, "Youtube Channel"] = "UCIbFhmYOqhvrudtVZG5-KEA"

#Index:  545
#UC7ga3FLMFOOpMQwaYoW42bw  -  UCewJXiU0kotMeq4iW9N-Yig
channel_yt_twitter[545, "Youtube Channel"] = "UC7ga3FLMFOOpMQwaYoW42bw"

#Index:  724
#UCuVxaQDraOja6xKidcmoufA  -  UCNB7H1Qqmb0BxmZGcsLTDJw

# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_14440/563420014.py in <module>
#      37
#      38 Index:  1160
# ---> 39 UCC69dxCZQB9VURlHQ8wesPA  -  UCpxHilQNhaFSxuPi9j9ZZ9g
#      40
#      41 Index:  1223
#
# NameError: name 'UCC69dxCZQB9VURlHQ8wesPA' is not defined

# %%
"UCGrUeq1FtRamLqZgaCIgB3w"[2:]
# Out:
# 'GrUeq1FtRamLqZgaCIgB3w'

# %%
# 7th from original, 6th from ours.

# %%
channel_yt_twitter = pd.read_csv("D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/data/5.1 get_yt_ids.csv")

# %%
#https://www.youtube.com/playlist?list=UURvUQd-GsCR97qKReTE89jQ
# channel id from "Accountable.US"
channel_d = "UCmX0gITcFMtmDSah8-wCChw"

# to scrap all the videos information from a single channel,
channel_get_all_videos_playlist = "UU" + channel_d[2:]

# %%
session = requests.Session()
header = {"User-Agent": "Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"}
response = session.get("https://www.youtube.com/playlist?list={}".format(channel_get_all_videos_playlist), headers=header)

# %%
if "XSRF_TOKEN" in str(soup):
    print()
# Out:
# yes

# %%
session_token_begin = response.text.find("XSRF_TOKEN") + len("XSRF_TOKEN") + 3
session_token_end = response.text.find('"', session_token_begin)
response.text[session_token_begin:session_token_end]
# Out:
# 'QUFFLUhqa0xkaGRXSk90SGcxWmRJcnlJWHRrWktiLTVFUXxBQ3Jtc0trQnRQZXhFamIyNzhhall6REtlUUJadDZtUXVQRkNyT3U3QmRXUlJWdkoyV09kbFBpV0pNVGYwR0lyS2sxU01WZkhPSzJQZEdQZDkxSFlGdDh2MTZsUkV0aUZGRDJ5NkxXUDNxLUo3U3pvZnktdkU1dw\\u003d\\u003d'

# %%
soup = BeautifulSoup(response.text, features='html.parser')
aid = soup.find('script',string=re.compile('ytInitialData')).text
aid = json.loads(aid[20:-1])

# %%
playlist_videos = []
for video in search_dict(aid, 'playlistVideoRenderer'):
    playlist_videos.append(video['videoId'])

# %%
playlist_videos
# Out:
# ['Xvs6XllRjrs',
#  'PZatsLWzIDQ',
#  'o68dOcApOAo',
#  'ByFRhIqek90',
#  'UQFtfhhtkC0',
#  'T1ONVWVIl3g',
#  'OStYvzKpkl0',
#  '7A4ZCjXzCzQ',
#  'vcPef46ptN8',
#  'd7avOs12ej4',
#  'TBfG4P5Jclk',
#  'LBiq-TR0fKU',
#  'btaw72KFWVk',
#  'dhp874XsDss',
#  'M3V6GNRfbTY',
#  'iEsfeasNBsE',
#  'CrOkNof-OLc',
#  'CPkqcj-Jz-M',
#  'ANnW74vgBaY',
#  'mXVrJecN3hE',
#  'rpis4TRfHdQ',
#  'CQzVO5TZsBE',
#  'hCsHo8xpNuk',
#  '2JWGDOH-HL4',
#  'OZLVzFGIfQI',
#  'ybPjJhT7xOw',
#  'kxlyOYV0IL4',
#  'Vw4f8oUIaC0',
#  '_SM40q2RWCc',
#  'QkkywUTaXwo',
#  'aLG2H4V-Bms',
#  'sRWsTsD-qfo',
#  '5ekUNXSKgAE',
#  '-l6gvV3q4SQ',
#  '8I5yst3nv58',
#  'fMS2dQvM9sI',
#  'hx2fH3tZOTA',
#  'fYNF10n31Mk',
#  'XeYK9oJUpYk',
#  '7TxlwD8_nR4',
#  'MaUJdLe8pj8',
#  'gxkueUR2y7k',
#  'kG5G13lOthI',
#  'SemHA4uhM90',
#  'Q2TJwzxbRBU',
#  'Grckl-se6Y8',
#  '37E0FE6BKhE',
#  'OdP3Ovm2UPc',
#  'RZqtizsR_3o',
#  'pg-IsBu1WL0',
#  '4sWm5qnjToQ',
#  'fmqjDYiOYac',
#  'M5bH1qLwAEQ',
#  '07no3gyDoBA',
#  'ENKXM6bTYGE',
#  'gRbiQRJIfAU',
#  'zqcPWYZKV9o',
#  '48_A_TJ0KNo',
#  'NGQevTehl-g',
#  'A7kY9q_KIvs',
#  'iqmBq2TVQ1M',
#  'UlQcJxYeH3E',
#  'Kz1gp5LGEnE',
#  'j5ozyFtFO1Q',
#  'N8XvVjKgsN8',
#  'GNHzSgp0wOk',
#  'bh8ZA-cjUxE',
#  'tbbWZwDRXoA',
#  'GjcLl4gCdtc',
#  '-0enGtHcdBQ',
#  'dDUS1lAy_3g',
#  'kPHC-TmTPKw',
#  'xUXplMllqss',
#  'b-m98H2Bybg',
#  'dDEoWbKQ2BA',
#  '0Zs3KQfGry0',
#  'jHc-QRiZOQg',
#  'y28NbXmoL2I',
#  'HPl3BdpZ_Xw',
#  'hdeckxB1KXE',
#  '1MpPnYQY2_w',
#  'ZBKtI2q6EnU',
#  'sxLa48c8Loc',
#  'wIo4ctKjrk8',
#  '9EQ_3SPQ4kE',
#  'uGx0QOa0mnY',
#  'nY46KemuEBM',
#  '0rLj2_Rbz2I',
#  'H9J734NbOJQ',
#  'avi8_IEJSnQ',
#  '65sXi9tEC2g',
#  'Uggim7one8w',
#  'XBYZ37ZUqrc',
#  'v5IWb3UkHBg',
#  'JTvsC9Xqegc',
#  '5fe_C9GmqaY',
#  'ts1PU8o17OA',
#  '5xojHflc_Zo',
#  'JGS0h6yQQjs',
#  '0smC18V2d7A']

# %%
def ajax_request(session, url, params=None, data=None, headers=None, max_retry=5, sleep=20):
    for idx_request in range(max_retry):
        response = session.post(url, params=params, data=data, headers=headers)
        time.sleep(1)
        if response.status_code == 200:
            ret_json = response.json()
            print("ajax...", ret_json)
            if isinstance(ret_json, list):
                ret_json = [x for x in ret_json if 'response' in x][0]
            ret_json.update({'num_request': idx_request + 1})
            return ret_json
        elif response.status_code in [403, 413]:
            return {'error': 'Comments are turned off', 'num_request': idx_request + 1}
        time.sleep(sleep)
    return {'error': 'Unknown error {0}'.format(response.status_code), 'num_request': max_retry}

# %%
START_DATE = datetime.datetime.strptime('2021-01-01', "%Y-%m-%d")
#https://www.youtube.com/playlist?list=UC7QxZdogxV1gloaOBO02wiw
# channel id from "Accountable.US"
channel_id = "UCRvUQd-GsCR97qKReTE89jQ"

# to scrap all the videos information from a single channel,
channel_get_all_videos_playlist = "UU" + channel_d[2:]

START_DATE = datetime.datetime.strptime('2021-01-01', "%Y-%m-%d")

playlist = scrapetube.get_playlist(channel_get_all_videos_playlist)

playlist_videos = []
selected_videos = []

for i, vid in enumerate(playlist):
    #print(i, vid['videoId'])
    playlist_videos.append(vid['videoId'])

print("There are {} number of youtube videos in channel id {}: ".format(len(playlist_videos), channel_id))
    
if len(playlist_videos) > 0:
    for video in playlist_videos:
        earliest_publish_date = get_video_date_upload(video)
        if earliest_publish_date is not None:
            print("date: ", earliest_publish_date)
            if earliest_publish_date > START_DATE:
                print("ADD: ", video) # return
                selected_videos.append(video)
            else:
                # since all the videos are in order, we do not want the rest of the comments form the videos
                print("Dont ADD")
                print( selected_videos )# remove break and add return statement
                break
        else:
            print("Received Unknown type of Date: Passing ... ")
print(selected_videos) # return statement
# Out:
# 0 6HbQznTtpdc
# 1 eprgk89suP8
# 2 xPkhjBkXsUM
# 3 yFUIRd1XvAU
# 4 8N3GvJZvUx0
# 5 ckstcCFUIfA
# 6 bwFtTZoY32Y
# 7 84y_CX1t8NY
# 8 FdkPeedeU34
# 9 J5L3NIRfBIM
# 10 6Sz3uodTGio
# 11 nOyEE2SAXvA
# 12 g-XSt7aZyGs
# 13 ehSaomQGxlY
# 14 1HojTZkllC0
# 15 R3LJWoSBkRU
# 16 pBpl9UtPfsw
# 17 1PLacAEWvqM
# xxx private or unavailable video 6HbQznTtpdc
# date:  2021-06-15 00:00:00
# ADD:  6HbQznTtpdc
# xxx private or unavailable video eprgk89suP8
# date:  2021-06-15 00:00:00
# ADD:  eprgk89suP8
# xxx private or unavailable video xPkhjBkXsUM
# date:  2021-06-15 00:00:00
# ADD:  xPkhjBkXsUM
# xxx private or unavailable video yFUIRd1XvAU
# date:  2021-06-15 00:00:00
# ADD:  yFUIRd1XvAU
# xxx private or unavailable video 8N3GvJZvUx0
# date:  2021-03-09 00:00:00
# ADD:  8N3GvJZvUx0
# xxx private or unavailable video ckstcCFUIfA
# date:  2021-03-02 00:00:00
# ADD:  ckstcCFUIfA
# xxx private or unavailable video bwFtTZoY32Y
# date:  2021-02-08 00:00:00
# ADD:  bwFtTZoY32Y
# xxx private or unavailable video 84y_CX1t8NY
# date:  2021-02-08 00:00:00
# ADD:  84y_CX1t8NY
# xxx private or unavailable video FdkPeedeU34
# date:  2020-12-30 00:00:00
# Dont ADD
# ['6HbQznTtpdc', 'eprgk89suP8', 'xPkhjBkXsUM', 'yFUIRd1XvAU', '8N3GvJZvUx0', 'ckstcCFUIfA', 'bwFtTZoY32Y', '84y_CX1t8NY']
# ['6HbQznTtpdc', 'eprgk89suP8', 'xPkhjBkXsUM', 'yFUIRd1XvAU', '8N3GvJZvUx0', 'ckstcCFUIfA', 'bwFtTZoY32Y', '84y_CX1t8NY']

# %%
import scrapetube

playlist = scrapetube.get_playlist("UU7yoXZ7c8ZZAimgcqHBtHoQ")

#for video in videos:
#    print(video['videoId'])

# %%
for i, vid in enumerate(playlist):
    print(i, vid['videoId'])
# Out:
# 0 hJCEOzOAy1M
# 1 cqgckQ4aeOg
# 2 OrzIl-l1kdQ
# 3 zzPGa-Pb--4
# 4 qikBF4Skdvo
# 5 YpEsQbLWxI8
# 6 wzWNlV_uF0E
# 7 vuzc3QEOHUw
# 8 efZAb7nDbSI
# 9 UydBMNB7tIM
# 10 8fldYKLVusY
# 11 dez7Nj2euKo
# 12 S0RZFA65ao4
# 13 SxIfWFqFbwo
# 14 hQ4rUdgE47A
# 15 zdoLEQqqmMk
# 16 GpeuxofU0fQ
# 17 QQCJGXLPdUg
# 18 TGikc7kIYAc
# 19 GU_GhEqPdv0
# 20 5HxbJtUF5rc
# 21 CbGt1OY7aIQ
# 22 sXLqH23TTTI
# 23 fYod174Ufz0
# 24 wZpIW4EuJyU
# 25 D3MU2C1poko
# 26 Hu-lEJ8VaKI
# 27 ZbZ0OSZwzQM
# 28 OpY9pnJIIDc
# 29 np1wg0AxW9Y
# 30 YSqxpDz_h4s
# 31 Hp8fLte82QE
# 32 ie6-QVi9DKM
# 33 HHpDN3R0qTo
# 34 R6cFBSX2NWU
# 35 ha6xIn7Z-Lk
# 36 ZCVS69vUtyk
# 37 q2-fYa3jGkg
# 38 30pH7bKfKD0
# 39 Npc0Sheoq-Q
# 40 nVdX-DtKcyQ
# 41 ar9PVjnfXRM
# 42 O8FhdbgLBPQ
# 43 C9gj7qpxT2c
# 44 nGs140rJjeQ
# 45 RqPS9foatBM
# 46 mBGyvVCZDMY
# 47 l0OkgQg0Dts
# 48 XroniYwmQ9k
# 49 RCZTLbHb7yc
# 50 PPbvc9xiEjQ
# 51 MWgB6huv3Qk
# 52 KuXWWdo8RyQ
# 53 r4-85wRdKQw
# 54 a_Sp0Ze_19k
# 55 uvEn5-e3ack
# 56 Fq2ZeFGQ4n4
# 57 lTKJsO0vyis
# 58 -WjvcKR0eWU
# 59 tCsky1hsYHc
# 60 9btSyZo1KCY
# 61 b-KvsfjCuX4
# 62 GS0mQxXBa38
# 63 SeWDjDV95Ts
# 64 HXdKYJ5wCrM
# 65 QC1L3xX_WLk
# 66 6vbpxVVmktA
# 67 ECcuaFPe4bo
# 68 6M4NFCKGpkk
# 69 Yfln1VxEAh0
# 70 i9ZMhb8ifY8
# 71 cchdQaHEEfs
# 72 YYxqOk8_jqE
# 73 IKKm4Vlfpik
# 74 4UpRLIT4rBU
# 75 XRIBOB40kPk
# 76 RoRx3H87sBs
# 77 3VBGah-kwvs
# 78 V1bkQ_O_EsE
# 79 HoG3Co8QPbo
# 80 NetsxFAoMF0
# 81 NFdB-A1vgR8
# 82 XngS-F75-qA
# 83 _EISRykdp5U
# 84 33jrbzkPFeg
# 85 XVK4OxnRdp0
# 86 GZw6FzpEWtE
# 87 Vppj4EHVqoA
# 88 FKhc4jpjQa0
# 89 guQD-WACap0
# 90 GOPxI-QrL2A
# 91 ONhRdOrnAtI
# 92 qlKAR9HizjQ
# 93 eS7q-BdJzHY
# 94 yaxP9HCkPtY
# 193 SSruG1fQnns
# 194 FmRFfFBWZOY
# 195 y3zK9VVc01Y
# 196 xV04ELjMTd4
# 197 koxnLt1k5P0
# 198 fqt0TaOCjvU
# 199 qzIRgh6PRaM
# 200 0-B0BpuBZJ4
# 201 B-JEY9KTCBc
# 202 AivtqZ5u6Lo
# 203 Vxjzn0cw6TE
# 204 w_Z83wixzOw
# 205 cs5lW36b4S4
# 206 C5rvAY0d5zQ
# 207 Gqbf-FadSHY
# 208 B2x7C4Z4r_0
# 209 oC1Jz-3AiNg
# 210 ke088sMPJ34
# 211 h9nKRhgZ5qI
# 212 drmBfN7Lw6g
# 213 fFnC0-cA2-M
# 214 zGefKUMRH1o
# 215 UR8C4OS4Trc
# 216 ZvAA2wqDZoU
# 217 mwcuE_m2ZKo
# 218 MN-CUNtZGMo
# 219 ieAAHvyOh1E
# 220 IoCMA1S0BqU
# 221 BszNjIRfP3c
# 222 eHlbQ2j5AWQ
# 223 y0tg2FurdV0
# 224 dSEuY1ciryk
# 225 vaoPeVXtwis
# 226 bcWq3f94rGg
# 227 ZSPH6Mwiq-0
# 228 chgs5-rOChA
# 229 uob9xHQU9Sw
# 230 CV6V3NXK0Sw
# 231 CTCxbjSS_Sw
# 232 ir7yvBDaF6k
# 233 zDe4KHDqsfY
# 234 hubV-ClvgEc
# 235 cFcpFcyyor8
# 236 Q7IjeB7Xnx8
# 237 uM-USgzAhJ8
# 238 Ogaj2eOSi2s
# 239 Sk7rwwEKFj0
# 240 nIsRlbV5sEI
# 241 2wVN8FXXnZI
# 242 JhGCIpBIztE
# 243 D9GjhQiMCVg
# 244 3pOwzPjbNtk
# 245 Ji6qxQ6wD_s
# 246 wPmzxcQpcG4
# 247 QOCDDsjOsnI
# 248 c6Eg_YehjMY
# 249 id-kS8R-kl4
# 250 FS5v9eUdyrY
# 251 -TLgN6Pwj7M
# 252 RB3A4vR9XP0
# 253 6ckm3p6TpG4
# 254 ej6JmTfLP90
# 255 Er-ErzmhNBc
# 256 -dd_EgnIdJM
# 257 LIk8tfK_3Zo
# 258 D7f2h4hLUJE
# 259 nGZPfmoT4hU
# 260 KlR92KDnHlk
# 261 cvJVBRAPZ6A
# 262 RHfMHwwVRpE
# 263 krJOmXNUn6c
# 264 Zy39rTP3Yj8
# 265 f-am0zggsCc
# 266 8scJE82ou2Y
# 267 lT5r_OE39kc
# 268 otz-JmztMG4
# 269 ZT3QCNa8f7w
# 270 YDr6AVnaU1o
# 271 EwIcDum54g4
# 272 LtLHXtoj8hc
# 273 hFWyI-J8vEE
# 274 Mz4c5uH_F_o
# 275 ab1OwusntKc
# 276 v8Hn1L2YQls
# 277 BrFs2bZwx6o
# 278 FWW7AlzqiCY
# 279 1Un0xnvt3UY
# 280 rylA6wSLfPo
# 281 AR2jrSdToj8
# 282 hyQKAHNvicw
# 283 1Eb66FmN4FM
# 284 KitBpCvb9NM
# 285 FrRlkN5QyZo
# 286 DHW4oq_U3h4
# 287 jvWN1jHAP0s
# 288 ydzteXNoJB0
# 386 -Tp1wPvkDHY
# 387 AH8tRwJuGvc
# 388 QWT6o6TUqj8
# 389 8Nzu0V-as_s
# 390 LRBUEsj25M8
# 391 ltZkUEXEr9A
# 392 nm8-qfCbI0g
# 393 2PLkUuV5Xug
# 394 dpYQ5UnuAYk
# 395 cpbMa755Kag
# 396 5mhDxNlThhU
# 397 uS_QE9FM3yA
# 398 TWK3rvn-GhY
# 399 CE5z-sbHfLo
# 400 i2FTS2e4aCk
# 401 ZykdK-mnQ4E
# 402 88wSp_xfwlQ
# 403 MPWZEP-6BTo
# 404 Wxqj136cVQs
# 405 NtfOggJoQmw
# 406 bC7rA0vXAms
# 407 dkg7vloSMhY
# 408 0bi-NaHseM0
# 409 8FCQH6ltmjo
# 410 t3MoiV-0ODU
# 411 EP749iJyIq4
# 412 OXE8P8UHh-A
# 413 9XGjS_Dm0KU
# 414 Nf78e0woZd4
# 415 PNYXs5edy1k
# 416 5EzeJAwI2kA
# 417 Dj8gHWMnmno
# 418 74Hq_qTOnL0
# 419 hzkxjpuPVLE
# 420 QEYhveN2nUM
# 421 oCCgU047Lwg
# 422 uGtbapbF528
# 423 wGemBjmjnI8
# 424 ZTzocJfUjSk
# 425 XExKVYamhCs
# 426 LJn6bcAdap4
# 427 cRmjonTsd8U
# 428 vH7vx90oPTA
# 429 EYXFFl8iKhc
# 430 3YKN_z71Jp0
# 431 Q4nT4KW6z5A
# 432 F8ZiEefuqug
# 433 2l2FlldvGoc
# 434 Q4TH-dXGZhE
# 435 lWBKFwKcCwA
# 436 HTIaVl3NizA
# 437 w3pxpnyPc9E
# 438 9iscZVipjh0
# 439 4Yy6OQOemjA
# 440 _0uBgnR0CM8
# 441 4ZnOXMkCwv8
# 442 i3ksF3J-_u4
# 443 WXKaXmoYj4g
# 444 EAAi7H474gs
# 445 YuyVEaKNPi8
# 446 PyCJRDWyt78
# 447 v-ngVpHuHhA
# 448 0oMCFRclQx4
# 449 PstcHGTfUQ4
# 450 _DCUlglMIEg
# 451 Jv7tARAcJ9s
# 452 hn-_Wkt3zeA
# 453 W4DXWQrfogs
# 454 XTO8JUesf3w
# 455 6Wg-Xzu3tKY
# 456 8MM3xT-RVrY
# 457 WTaygm5wi9g
# 458 Vbgubzn_a0c
# 459 lp0et-WJzVE
# 460 ooim5_eul4E
# 461 Oy5zbSNFxMs
# 462 _jzY2RJAJ48
# 463 daOlaQceGDQ
# 464 auw4nO6w6wU
# 465 WFi_b3BGlbQ
# 466 L_hsEembGBc
# 467 lxdrEB6ymvQ
# 468 Qisu0nL0DHc
# 469 LT1sLSy_JUA
# 470 kkaqBQczNN0
# 471 eKHfzxMDr9A
# 472 maNaOG-fEoo
# 473 NMR0ULYfAyc
# 474 gYv6BfbbBvk
# 475 Ns6P-7_7dSc
# 476 Z05mEmggxto
# 477 J9j_K-ZIKd4
# 478 HgjATV1zcv0
# 479 quN5qSIEs1Q
# 480 AXp8vObA7S8
# 481 ATJJFiaODAg
# 482 oqWlHpDGALY
# 483 USHGhAtJM70
# 484 MZiXqhba5Eo
# 485 zG4cDTqaxOE
# 486 d1iYkQQMxkM
# 487 aojLMIlwKqo
# 488 GKMizzOn4MA
# 489 PnhA-HzyvwU
# 490 n7DOJXjUyqI
# 491 _n7o92qKwuU
# 492 6F94fxwBJQM
# 493 1l8sOMfctEE
# 494 f3s3_haaYIc
# 495 FtFU7LjAU-Y
# 496 kIRh_5pGjyA
# 497 8cR3QtvBP9k
# 498 UtObwU7f0MU
# 499 C5kSN7cJcns
# 500 V2eVf5NjqTE
# 501 gJFgzA4sDHc
# 502 ERm3028PVoA
# 503 PnGu1pAeHN0
# 504 qi3mFH4ngzw
# 505 6nznAReYer0
# 506 lS7j0U0ilIs
# 507 4DePz8_iRFk
# 508 SaJ9ydgULO8
# 509 3YpmjmQcn0w
# 510 b9jC_V33s60
# 511 j5awjr6N5o8
# 512 faAbUT9L5JA
# 513 JHy9hpEFyig
# 514 B6O5in67vqE
# 515 cnlSEvsR7as
# 516 eNZTaMs9fZI
# 517 6vFBPieeDJQ
# 518 CypAT6yXgUY
# 519 Sc5Ge4Wt7bU
# 520 BZyVjKuuSSs
# 521 kTXqJpqQ5cQ
# 522 Q8kNgY2Jjaw
# 523 OUHBra3O14c
# 524 Lr7WROIUiVw
# 525 Xo3_IYslI3w
# 526 U9cBWH_oaVk
# 527 H3Ex9O0Fff8
# 528 HIUP6ffT6K4
# 529 O90ZM-vnpss
# 530 q9tOc1S_DSU
# 531 wKIo3nITGBo
# 532 pa3WnVNsC3U
# 533 nVcCaTVijAU
# 534 eABU8-pCpGE
# 535 0MLH2_tAaww
# 536 OyC0E0ym2Ro
# 537 gkaEU7sZVqw
# 538 MiOmnCkuh90
# 539 OCfWjOCNRjY
# 540 qY0PggJ6cjo
# 541 bEP6EizZXtQ
# 542 _JAt5w8FX0k
# 543 P960Tc8BuD4
# 544 DGn4hsfFUl8
# 545 LBjzMKoo4xs
# 546 Y5fzGhDGUO4
# 547 h3r13W8kHxc
# 548 9fYDpKmJAdU
# 549 X18e4NRUVIo
# 550 I7y3AYqS6gs
# 551 S7cYL2KdI1U
# 552 bjM0V3sTwS4
# 553 2TFU-na43wI
# 554 -ExBmtJQVdE
# 555 QuMKbr3Yoko
# 556 k7SVHWuqyQ8
# 557 QRLXN0168xI
# 558 l2Zfj6dkBbk
# 559 S-3OwBgS6mA
# 560 tsZZ5Ss0cDI
# 561 _Do6APj1te0
# 562 BMkDfDTuX6E
# 563 JIwppJLJZbY
# 564 q9TA8RGowQE
# 565 5b7hhrgPBSU
# 566 uJ8Qsklesgo
# 567 7wAL9uqq4Gg
# 568 gDA_TF47oDY
# 569 t98-C3Nk5P0
# 570 9Urxi8-TPX8
# 571 YTYHnKc5JP8
# 572 lzOBpqjmr7I
# 573 tiDyTtQA5Dg
# 574 41dCHBeG29Q
# 575 AsLX5MW0tQ4
# 576 rr_2Khu5wxY
# 577 vTVC8q0Mj9U
# 578 ZQs9CGdpmwk
# 579 WAkoBcxXp5I
# 580 zDUl4T81RZg
# 581 RZoP3zvRdpI
# 680 0gcWVwibxPs
# 681 LVWxfuCE6sU
# 682 NAuOFWxMmDM
# 683 V11nom5fD50
# 684 CLBI6LOYGoA
# 685 hJpait_nTew
# 686 4HgK_tSrmJA
# 687 uFuZWptmv3w
# 688 SI_vnkk_5So
# 689 tgQi1uN4CVY
# 690 8r3zVUnPb94
# 691 GZEhMzNLEMw
# 692 Z6CtRNuXJRc
# 693 lg4LrDvxiA8
# 694 D7gdMnZhRgU
# 695 4H1pMXALeGk
# 696 m2_Ld5OGGcI
# 697 9eF2EIj80Ks
# 698 wvwRAqPxWPg
# 699 IpZ_TgQOLv0
# 700 ALQ1hXF9JTA
# 701 QPquJyK099Y
# 702 4fVd6eJuaG8
# 703 Kz6hgIJVU5c
# 704 CL50SKJbUw4
# 705 N4SAiCx4igc
# 706 NNzQxHZj3eU
# 707 6XcTz3uM4uY
# 708 9d21Wqwim3o
# 709 ya3D5cApZs4
# 710 vTC_hbkeBF0
# 711 gIo5JqbKtEw
# 712 sRgr2dkBA-o
# 713 67wbJzAMo6M
# 714 PiClVs8rgi0
# 715 FRCzda2dI9I
# 716 WpfdzGA3j-w
# 717 ciKuu06gNlY
# 718 jyj33JGxb10
# 719 nL2S-nqDBw4
# 720 KZAx4sZZM8A
# 721 fQ6PYR_ZQnY
# 722 Txe790gOmQU
# 723 gzDuTmIKhc0
# 724 ANxDDzhNl2Y
# 725 ivosUs_jlTE
# 726 nUYw1-uR7-s
# 727 JxqTjeQA2QM
# 728 pJeGnLsuOq0
# 729 vgc6alzYLBw
# 730 m95cKO1YeYw
# 731 PJ3KUBg1RaM
# 732 4RcfWKAMt3Y
# 733 iG_ifot_WkI
# 734 i3zk9KZancg
# 735 iM0eeP6mTW8
# 736 K48I1fqwO88
# 737 GDOGK0n3X6Q
# 738 Um0AiPAOJac
# 739 Kt5Y7mTT8N4
# 740 -OCwyPM693c
# 741 CFxY9wH8tKM
# 742 -46RP7N-180
# 743 L_nxMOq_YqA
# 744 1NLLMzj_Kyg
# 745 ku4SrF0JQsg
# 746 yqOAlvMVftQ
# 747 oaTRIzoq3xY
# 748 4EahrMLUn6o
# 749 Lp_Iy2bwD-w
# 750 QOWDWSWxE-w
# 751 ycYk1yZ061I
# 752 YrwYHMo8mwg
# 753 fUHhH4Y6NfQ
# 754 b_8FxUDFTdQ
# 755 gSY3NaVQ54s
# 756 CkHDgNYHkPg
# 757 BqRcTsHWCJ4
# 758 2RUVep5Ggp8
# 759 iLgbI7IMKAM
# 760 msQe6HqOgdg
# 761 HXP0GvK3Nz8
# 762 oZn9AVv3Q_Y
# 763 NEYVi5F4Z5Q
# 764 Dv3B6dvmais
# 765 vi2xn-3jbB0
# 766 aP0uyFfbzVM
# 767 h0WDCZblbOA
# 768 mkFLCLiajbk
# 769 rkfTxr6VQOY
# 770 aM8zrecPT9I
# 771 htCqwy-5dIQ
# 772 e20Z9bsoyD8
# 773 U-ChvSV6Z9w
# 774 APg4_EhFAmI
# 775 Nh339vgN8Fc
# 776 TnOqF5pySGc
# 2999 N5NN2hkg_xI
# 3000 LTD2hUicVIA
# 3001 _visHrMIkls
# 3002 pRPXtk1MiYM
# 3003 wVjDGkegS20
# 3004 W0SGq6EN90Y
# 3005 wZ3Gf1G8WfE
# 3006 jiwMCAkK9uE
# 3007 xlk_1QllQSA
# 3008 6bKY3usjipU
# 3009 17q-LxD0gHw
# 3010 Ku8hXRkeCj8
# 3011 MXa3YtOCSIo
# 3012 zgT5HdeXGfY
# 3013 h2QVPsiE8To
# 3014 _X3bOQdvTpQ
# 3015 G097EssrGcw
# 3016 i_nYnx4qtIg
# 3017 vbciw7MD6cQ
# 3018 pWWWfn_I-IU
# 3019 QWJ1hoWdLYw
# 3020 ZgLH1FnJSHk
# 3021 SD4VRXlsoWA
# 3022 5HwNVpEuSF8
# 3023 h74W5T1iAY4
# 3024 pYeqrOl1oUc
# 3025 6HRjT-3-mIE
# 3026 AUUboBcvq2w
# 3027 CaOSuq6PicY
# 3028 p1wLTvzZJlU
# 3029 rpsUXTBZl9k
# 3030 WPu8WdnAm7s
# 3031 3bBCVS1ebcY
# 3032 nWhhH0cLAXc
# 3033 jUYf0YOUXXc
# 3034 pwCtGZG6IEU
# 3035 n-pRAyDq458
# 3036 1vaIZijhwnQ
# 3037 S7tzSNbCrnY
# 3038 8QRh1uWraJc
# 3039 Dk5JkodxlII
# 3040 NrcSbaFrLzU
# 3041 ZhvesX5DhQU
# 3042 4OhfweUgA3c
# 3043 64vMLtvgIdk
# 3044 bKQiqT2ehEU
# 3045 ypV64YabVNM
# 3046 m3092cPJDJ4
# 3047 c1_Rb3-AacU
# 3048 h6uDJz8Rl-8
# 3049 Mq4zybNU364
# 3050 Racvwc2CjZM
# 3051 G3d0Cnj6wck
# 3052 K8Ynmzmnr5M
# 3053 UsdfeSnHy8g
# 3054 SVYygx_omcs
# 3055 VMmJWKnDD-4
# 3056 hCVSVCdxNoA
# 3057 -NTtMdavT7o
# 3058 RuGNJxeovbE
# 3059 Lr8bQR_itxI
# 3060 ps7Ir6TFEQ4
# 3061 _DueboPHbQ0
# 3062 M4RoHyNqxbM
# 3063 p33HpbsjRCQ
# 3064 JdOnQM-U-h4
# 3065 PXXZgxrO_vA
# 3066 GPV7Fx6Usmo
# 3067 IdF9PKIOWP8
# 3068 8tvd2jM-b5M
# 3069 EZjSXdHHeDs
# 3070 ZJ-aBjBiEt8
# 3071 il2iRc9VDi8
# 3072 GeZjVsYfmfk
# 3073 PmpVhJsOQEE
# 3074 WTB0X-ORi6w
# 3075 kCotRderDN0
# 3076 ohgEsyh7V7E
# 3077 5s26_af5iNI
# 3078 pc0wi7dSUa4
# 3079 JAymKvgpIeM
# 3080 1bI2n6FWHXY
# 3081 tjhc-2_rZFw
# 3082 b7M1zSh8kFw
# 3083 6TF3cj49zHw
# 3084 2QcjD6tVRc4
# 3085 sVez6TMmuRQ
# 3086 bP-WKviMIiI
# 3087 3ZaL96Piygk
# 3088 Ra8_xM8XWsA
# 3089 t0rW9l3k3JI
# 3090 sZCGgh3v-Vg
# 3091 Gsh1YU_7joM
# 3092 4DK4zqLztw8
# 3093 PzW-1Ug3NdM
# 3094 023T6Z_pR_M
# 3095 KRqyEjivEaw
# 3096 5_Gnjt43t-k
# 3097 Er08Ddi0Fpk
# 3098 fMbwmh-SPe4
# 3099 feelu2mBhRM
# 3100 U9eMFJloeds
# 3101 lastrPUWcGU
# 3102 6KpEzZe4gZA
# 3103 BoPghOdmkuU
# 3104 9-nXq-_aHRU
# 3105 vrCb4tcOjqw
# 3106 _p0m_pAjRGU
# 3107 Fwnwbed7BUU
# 3108 JCIudI4emI4
# 3109 i_W3T40vTT0
# 3110 xLfp6gL1gOU
# 3111 EVlztjHwTBo
# 3112 DhxCAYLyFno
# 3113 zCt6r_GJ-XQ
# 3114 WICG_Qfkj5c
# 3115 Dnu_1oZf0cA
# 3116 _YKmQGitFII
# 3117 vMt19h0vrgA
# 3118 qWK3gRllvzE
# 3119 70rhiO1-N7k
# 3120 MXznLzUEjnM
# 3121 YZmtwfPV7fE
# 3122 z7sbamdeD-I
# 3123 P7Rrc8Ri0n0
# 3124 _j62o2TLG9A
# 3125 _PAAXqfN4T4
# 3126 OXJ7E0TZdOA
# 3127 bWaECc_OL6I
# 3128 E7VLMCjIhjE
# 3129 eXmpkm3q4Sc
# 3130 l9hwvPae39U
# 3131 moGLVFiw1h8
# 3132 BKhONL1TV_g
# 3133 S_RypWanGiQ
# 3134 B8N314FJgNw
# 3135 enp87L2-6mg
# 3136 td54hw80voI
# 3137 d-ALSC5-5AY
# 3138 tVkQcwneNpA
# 3139 75aICt_Ct9E
# 3140 A9xAeSTSzg8
# 3141 7wV5CuqCK5I
# 3142 wYSWfpiEVxU
# 3143 OfsZOXi4SJw
# 3144 FYZSKfycQYc
# 3145 vi_OQszTYx0
# 3146 3Ov0ynnldHU
# 3147 jRiSKUgaos4
# 3148 MeKyJOdlRDY
# 3149 GgeVlO1NoJE
# 3150 w623m2MSXFs
# 3151 QH5JirhRm1Q
# 3152 f8NpsO9JjKg
# 3153 4rkcZx4rF8U
# 3154 vxYz_Y4R0zU
# 3155 wx-ETECcMM4
# 3156 6-LzKvq-Sqk
# 3157 VulIcnPG1Ls
# 3158 fFkZtQQeRc4
# 3159 Cs9a2MbJMWo
# 3160 4Zyi6nSom08
# 3161 acu8_iCH3Zo
# 3162 xXL-XMCUUW8
# 3163 63_7GfhaF78
# 3164 rsnddSEPkvc
# 3165 TlgiUJFlF6I
# 3166 mmDt2D3iTiU
# 3167 _IemNpsurso
# 3168 pQeJmpaziX0
# 3169 BtYUgu6Ca7k
# 3170 v4F9pHrF7gI
# 3171 mJMsoltDJvw
# 3172 qQKZBiOkMLY
# 3173 q-EfZxzxXAM
# 3174 rJzPjTdoJ7E
# 3175 wb4TtepP7q8
# 3176 XWzzb2ctVkA
# 3177 A6H6gb611k4
# 3178 gJV9MKTcQBs
# 3179 Q4TSgm8v9_8

# %%
selected_videos
# Out:
# ['TP6dZzw-Kxk', 'Fto4UypE3IM', 'DFYiUsJr478', 'ORpGsJ-1kuU']

# %%
a = datetime.datetime.strptime('2021-01-01', "%Y-%m-%d")
b = datetime.datetime.strptime('2020-08-11', "%Y-%m-%d")

# %%
visited_channel_set = set()

output_file = "data/6. video_ids.json"

if os.path.exists(output_file):
    with open(output_file, 'r') as fin:
        for line in fin:
            visited_channel_set.add(json.loads(line.rstrip())['channel id'])
            
visited_channel_set
# Out:
# {'UC7QxZdogxV1gloaOBO02wiw',
#  'UC7yoXZ7c8ZZAimgcqHBtHoQ',
#  'UCRvUQd-GsCR97qKReTE89jQ'}

# %%
"UCRvUQd-GsCR97qKReTE89jQ" not in visited_channel_set
# Out:
# False

# %%
import datetime
def get_video_date_upload(video_id):
    youtube_video_link = "https://www.youtube.com/watch?v={}".format(video_id)

    session = requests.Session()
    header = {"User-Agent": "Mozilla/5.0 (compatible; Googlebot/2.1; +http://www.google.com/bot.html)"}

    response = session.get(youtube_video_link, headers=header)

    if response.status_code == 429:
        print( None)
    if response is not None:
        soup = BeautifulSoup(response.text, features='html.parser')
        aid = soup.find('script',string=re.compile('ytInitialData')).text
        aid = json.loads(aid[20:-1])

        if 'videoDetails' not in aid or 'microformat' not in aid or 'playerMicroformatRenderer' not in aid['microformat']:
            print('xxx private or unavailable video {0}'.format(video_id))

            for date in search_dict(aid, 'dateText'):
                try:
                    date = datetime.datetime.strptime(date["simpleText"], "%d.%m.%Y").strftime("%Y-%m-%d")
                    return datetime.datetime.strptime(date, "%Y-%m-%d")
                except:
                    return None
        else:
            microformat_renderer = initial_player_response['microformat']['playerMicroformatRenderer']
            publish_date = microformat_renderer['publishDate']
            return publish_date

# %%
# skipped number 8 script fro original
# 9 form original, 7th from ours

# %%
def get_video_metadata(video_id):
    timer = Timer()
    timer.start()

    print('>>> now crawling video_id: {0}'.format(video_id))

    num_block = 0
    num_fail = 0
    while True:
        if num_block > 3:
            raise Exception('xxx error, IP blocked, STOP the program...')

        if num_fail > 5:
            print('xxx error, too many fails for video {0}'.format(video_id))
            return {}

        session = requests.Session()
        session.headers['User-Agent'] = random.choice(USER_AGENT_LIST)

        response = session.get(YOUTUBE_VIDEO_URL.format(video_id=video_id))
        # too many requests, IP is banned by YouTube
        if response.status_code == 429:
            print('xxx error, too many requests, sleep for 5 minutes, iteration: {0}'.format(num_block))
            num_block += 1
            time.sleep(300)
            continue
        if response is not None:
            html = response.text

            prefix_player = 'window["ytInitialPlayerResponse"] = '
            suffix_player = '\n'
            if prefix_player not in html:
                prefix_player = 'var ytInitialPlayerResponse = '
                suffix_player = ';var'
            prefix_data = 'window["ytInitialData"] = '
            suffix_data = '\n'
            if prefix_data not in html:
                prefix_data = 'var ytInitialData = '
                suffix_data = ';</'

            try:
                initial_player_response = json.loads(find_value(html, prefix_player, 0, suffix_player).rstrip(';'))
                # print(json.dumps(initial_player_response))
                initial_data = json.loads(find_value(html, prefix_data, 0, suffix_data).rstrip(';'))
                # print(json.dumps(initial_data))
            except:
                num_fail += 1
                continue

            if 'videoDetails' not in initial_player_response \
                    or 'microformat' not in initial_player_response \
                    or 'playerMicroformatRenderer' not in initial_player_response['microformat']:
                print('xxx private or unavailable video {0}'.format(video_id))
                return {}

            video_details = initial_player_response['videoDetails']
            microformat_renderer = initial_player_response['microformat']['playerMicroformatRenderer']

            title = video_details['title']
            channel_id = video_details['channelId']
            category = microformat_renderer.get('category', '')
            print('>>> video_id: {0}, category: {1}'.format(video_id, category))

            keywords = video_details.get('keywords', [])
            description = video_details['shortDescription']
            duration = video_details['lengthSeconds']
            publish_date = microformat_renderer['publishDate']
            snapshot_pt_time = datetime.now(PT_TIMEZONE).strftime('%Y-%m-%d-%H')
            view_count = microformat_renderer.get('viewCount', 0)
            is_streamed = video_details['isLiveContent']

            num_like = 0
            num_dislike = 0
            for toggle_button_renderer in search_dict(initial_data, 'toggleButtonRenderer'):
                icon_type = next(search_dict(toggle_button_renderer, 'iconType'), '')
                if icon_type == 'LIKE':
                    default_text = next(search_dict(toggle_button_renderer, 'defaultText'), {})
                    if len(default_text) > 0:
                        try:
                            num_like = int(default_text['accessibility']['accessibilityData']['label'].split()[0].replace(',', ''))
                        except:
                            pass
                elif icon_type == 'DISLIKE':
                    default_text = next(search_dict(toggle_button_renderer, 'defaultText'), {})
                    if len(default_text) > 0:
                        try:
                            num_dislike = int(default_text['accessibility']['accessibilityData']['label'].split()[0].replace(',', ''))
                        except:
                            pass

            ret_json = {'vid': video_id, 'title': title, 'channel_id': channel_id, 'category': category,
                        'keywords': keywords, 'description': description, 'duration': duration,
                        'publish_date': publish_date, 'snapshot_pt_time': snapshot_pt_time, 'is_streamed': is_streamed,
                        'view_count': view_count, 'num_like': num_like, 'num_dislike': num_dislike,
                        'lang': 'NA', 'transcript': 'NA', 'num_comment': 'NA', 'comment_list': 'NA', 'top_comment_list': 'NA'}

            # early return if non-political video
            if category not in ['News & Politics', 'Nonprofits & Activism', 'People & Blogs', 'Education', 'Entertainment', 'Comedy']:
                print('xxx non-political video {0}, category: {1}\n'.format(video_id, category))
                return ret_json
            # print('>>> Step 1: finish getting the metadata via parsing the html page...')

            # 2. get video English transcript
            transcript_response = ''
            caption_tracks = next(search_dict(initial_player_response, 'captionTracks'), [])
            for caption_track in caption_tracks:
                if caption_track['languageCode'] == 'en':
                    if 'kind' in caption_track and caption_track['kind'] == 'asr':
                        transcript_url = caption_track['baseUrl']
                        transcript_response = session.get(transcript_url)
                        break
                    else:
                        transcript_url = caption_track['baseUrl']
                        transcript_response = session.get(transcript_url)
                        break

            if transcript_response != '':
                eng_subtitle = ''
                for segment in parse_transcript(transcript_response.text):
                    if 'text' in segment:
                        seg_text = segment['text'].lower()
                        eng_subtitle += seg_text
                        eng_subtitle += ' '
                ret_json['transcript'] = eng_subtitle
            # print('>>> Step 2: finish getting video English transcript...')

            # 3. get video comments via yt_comments package
            # You can either pass an ID or a URL
            # video_id = "y7zrjWp3fEk-3OmJ0"
            comments = Comments(video_id)

            while comments.hasMoreComments:
                try:
                    comments.getNextComments()        
                except:
                    print("Error ... breaking up the code...")
                    comments.hasMoreComments = False
                    break

            print(f'Comments Retrieved: {len(comments.comments["result"])}')
            print('Found all the comments.')
            
            print("Processing list ... ")
            comment_list = []
            for c in comments.comments["result"]:
                comment_list.append(create_comment_dict(c))
                
            comments.comments["result"] = []
            
            ret_json['num_comment'] = len(comment_list)
            ret_json['top_comment_list'] = comment_list
            #ret_json['comment_list'] = No Idea about this
            
            # print('>>> Step 3: finish getting video comments...')

            timer.stop()

            time.sleep(5)
            
            return ret_json
    return {}

# %%
import os, time, json, requests, re, random, bz2, codecs
from datetime import datetime
from pytz import timezone
from html import unescape
from xml.etree import ElementTree

from utils.helper import Timer
from utils.crawlers import USER_AGENT_LIST, YOUTUBE_VIDEO_URL, find_value, search_dict
from utils.yt_comments import download_comments_top, download_comments_time

HTML_TAG_REGEX = re.compile(r'<[^>]*>', re.IGNORECASE)
PT_TIMEZONE = timezone('US/Pacific')

from youtubesearchpython import *

def parse_transcript(plain_data):
    return [{'text': re.sub(HTML_TAG_REGEX, '', unescape(xml_element.text)),
             'start': float(xml_element.attrib['start']),
             'duration': float(xml_element.attrib.get('dur', '0.0'))}
            for xml_element in ElementTree.fromstring(plain_data) if xml_element.text is not None]

# %%
def create_comment_dict(result):
    author_id = None
    author_name = None
    comment = None
    date_comment = None
    num_replies = None
    
    comment_dict = {}

    if 'author' in result:
        if 'id' in result["author"]:
            author_id = result["author"]["id"]
        if 'name' in result["author"]:
            author_name = result["author"]["name"]

    if 'content' in result:
        comment = result["content"]

    if 'published' in result:
        date_comment = result["published"]

    if 'replyCount' in result:
        num_replies = result["replyCount"]

    comment_dict["author_id"] = author_id
    comment_dict["author_name"] = author_name
    comment_dict["comment"] = comment
    comment_dict["published_date"] = date_comment
    comment_dict["num_of_replies"] = num_replies
    
    return comment_dict

# %%
video_id = ["c0JlpI9-CtM", "evCcmN2ZTzI"]
processed_result = []
for v_id in video_id:
    processed_result.append(get_video_metadata(v_id))
# Out:
# >>> now crawling video_id: c0JlpI9-CtM
# >>> video_id: c0JlpI9-CtM, category: People & Blogs
# Comments Retrieved: 630
# Found all the comments.
# Processing list ...
# >>> Elapsed time: 0:00:08.992
#
# >>> now crawling video_id: evCcmN2ZTzI
# >>> video_id: evCcmN2ZTzI, category: People & Blogs
# Comments Retrieved: 577
# Found all the comments.
# Processing list ...
# >>> Elapsed time: 0:00:07.667

# %%
processed_result[0]
# Out:
# {'vid': 'c0JlpI9-CtM',
#  'title': 'Top 5 GODI of the WEEK | Toxic debates, Aryan Khan & No inflation for Tihadi',
#  'channel_id': 'UCbrgKz68f3NvLr7p3Oiw9nA',
#  'category': 'People & Blogs',
#  'keywords': [],
#  'description': 'For Business inquiries:  iamsatyakam@gmail.com\n\nLike on Facebook : https://www.facebook.com/Being-Honest-943485055835735\n\nFollow Us on twitter  :  https://twitter.com/TheSatyaShow',
#  'duration': '609',
#  'publish_date': '2022-05-27',
#  'snapshot_pt_time': '2022-05-29-16',
#  'is_streamed': False,
#  'view_count': '312910',
#  'num_like': 0,
#  'num_dislike': 0,
#  'lang': 'NA',
#  'transcript': 'NA',
#  'num_comment': 630,
#  'comment_list': 'NA',
#  'top_comment_list': [{'author_id': 'UCtzzwxiZdNvMRIfCZPkVP5Q',
#    'author_name': 'Pratik Kanthe',
#    'comment': 'You are the 4th pillar of Democracy!! Love you 3000, Satya! 💛 Keep up the good work on being honest and the satya show!',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': 13},
#   {'author_id': 'UCpFN_ImdBhlJv7SyznWV4pQ',
#    'author_name': 'Siddharth Shinde',
#    'comment': 'The duty of a true Patriot is to protect his country from its government',
#    'published_date': '1 day ago',
#    'num_of_replies': 2},
#   {'author_id': 'UCDqKTGG0RkxxaII8aX9Lj7A',
#    'author_name': 'Neetu Kaushik',
#    'comment': 'That is why your channel much better than our Godi media, ',
#    'published_date': '2 days ago',
#    'num_of_replies': 4},
#   {'author_id': 'UCasJcZ-Kj3Qud-lAzlEIKwQ',
#    'author_name': 'Rithic Singh',
#    'comment': "It's shocking that Tihadi forget Netaji.",
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': 4},
#   {'author_id': 'UCRUwQTV9fpzxPrJc-TyyW6g',
#    'author_name': 'Abhishek Tripathi',
#    'comment': 'Satya you and your team is really working hard. I wish you get more recognition but to be true in post truth era nobody wants to listen to truth.',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCP7hDgL1MNqL4uvNootw93w',
#    'author_name': 'Amol Bhavsar',
#    'comment': 'Modi\'s dialogue "OH MY GOD" is epic and used perfectly. I just can\'t stop laughing. 😂😂',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCiIZunz1WTzlkOorLyO4rIg',
#    'author_name': 'Sate De',
#    'comment': 'Would Tehadi’s kids feel pride about contribution of Sudhir Ch. in the field of Journalism. I believe his kids would never disclose their relationship with him.',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC7gYKxqg09QvNsisJwxKj8Q',
#    'author_name': 'Pencil Sketch_ Tarini P. Nayak',
#    'comment': "I literally couldn't stop laughing 🤣",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCoVoBb0Tc6kP7BTTvdTQQwQ',
#    'author_name': 'Shamsher Khan',
#    'comment': 'Your work is too good & very important at this time in Great India...  Salute',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCyEsg5-6grCWuj1uvf99XdA',
#    'author_name': 'preeti gouda',
#    'comment': 'Never told anyone in social media that I love you...but Satya I love you..you are doing great',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCwJ9t8JVSmJ-9Si-8hRYb6g',
#    'author_name': 'Vishal Nahar',
#    'comment': 'Man reading theTwitter is absolutely hilarious 😂🤣',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCkG9S9RJzOrT4XzAXEWvjZw',
#    'author_name': 'Satish Chouhan',
#    'comment': '4:00',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': 9},
#   {'author_id': 'UCbJQGPdOLwI8_X3yM-lbc4A',
#    'author_name': 'Hamid Hassan',
#    'comment': 'You really deserve bro as a main media of our nation',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCIG_9iWxm2TaAa2iQO72NFQ',
#    'author_name': 'Mahendra Chouhan',
#    'comment': 'Your r doing great job brother...this country needs people like you..',
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCN1otUMkH4wq1TPFQUdf35w',
#    'author_name': 'Hammad Chouhan',
#    'comment': 'HATS OFF TO ALL BRAVE HONEST REPORTING ❤️👌👍👏🇮🇳🇮🇳🇮🇳',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC_pMEzH8nF1i_qvymeKdINw',
#    'author_name': 'जुमलेंद्र  ऊर्फ बेचेंद्र फेंकुचंद',
#    'comment': 'currently people in India are not worried about their future (inflation, unemployment, hindu muslim riots etc. ) instead they are happy in digging their past !',
#    'published_date': '2 days ago',
#    'num_of_replies': 50},
#   {'author_id': 'UCKvPF7QFnHvmYGkYFwBXQ6Q',
#    'author_name': 'MBG',
#    'comment': "Satya bhai, create a news channel for common man's interest. You are doing fantastic work and will never be forgotten atleast not by me. You are striving to bring truth to general public when almost all media is biased. Thank you once again",
#    'published_date': '9 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCasJcZ-Kj3Qud-lAzlEIKwQ',
#    'author_name': 'Rithic Singh',
#    'comment': 'I apologise to u Satya because when u promoted The Kashmiri Files I thought that like others u would also do the same but covering kashmiris in every video is really Appreciable.',
#    'published_date': '2 days ago',
#    'num_of_replies': 4},
#   {'author_id': 'UCuIwOgJYK7KCmrcijwHV0ug',
#    'author_name': 'Nitish Kumar',
#    'comment': 'अब तो दिल से बस एक ही आवाज निकलती है.....कोई लौटा दे मेरे वो 2014 के पहले वाले "बुरे दिन".',
#    'published_date': '2 days ago',
#    'num_of_replies': 7},
#   {'author_id': 'UCxbgaIgGLaoVw-KrL65lMlQ',
#    'author_name': 'Anmol Rajan',
#    'comment': 'you are doing a wonderful job ,god bless you.Hats off and much respect to your constant efforts to expose these fake media houses',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UChC52_VNhm3fvKWk1Kfxhqw',
#    'author_name': 'viky kale',
#    'comment': 'Keep it up satya sir... You are the real journalist..',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCWnSzSELwJ1ZqbtgDGHNM-g',
#    'author_name': 'Mr Engineer, All Rounder',
#    'comment': 'Best reporting ever ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCC7n_C6MA45GRiziwblo0PA',
#    'author_name': 'Mohammad khaleel.happy',
#    'comment': 'Satya your work is superb! It is looking like collection of flavour in single plate.',
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UC_qAK8M-DgwcHCMOVLD642g',
#    'author_name': 'Vijay Yadav',
#    'comment': 'चिचा : कोई पब्लिसिटी नहीं मिली',
#    'published_date': '2 days ago',
#    'num_of_replies': 8},
#   {'author_id': 'UCBRcVkCWmfLY1LOuDqws50w',
#    'author_name': 'Jit Mallick',
#    'comment': 'You are doing an incredible work for us and also for those who think our pride our ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCMoAkmT-fKqnEzu-bXTz1Fw',
#    'author_name': 'Vikas Mongia',
#    'comment': 'They need issues to propagate the political agendas.. but when it comes to people and reality they fail to act as quickly as possible.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCpmbCUpbvoZ4kkeYyN5P8Og',
#    'author_name': 'kqaleyd',
#    'comment': '0:47',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCxMguUmdXtppPAcg0ALOJDQ',
#    'author_name': 'T2F Sameer',
#    'comment': 'I love this part ',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCwnWQx0Sy2yI8biJY5bsB3w',
#    'author_name': 'Radhika Shukla',
#    'comment': 'This is hilarious and deeply saddening at the same time',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCXBLtXVU-2HFEEbFSUTCu_w',
#    'author_name': 'shabir shaikh',
#    'comment': '1) I respect all religions, but a question comes into to my mind, only the children of the poors, farmers, daily wages labourers, small job worker, small vendors, self employed, unemployed belong from (SC, ST, OBC) they get involved in every riots and killed by each other community ?!',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCrjBpCcL8rFngbBTRpADekQ',
#    'author_name': 'Hetal Patel',
#    'comment': 'Love ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCohzxLtRB6IB-gp7Zahurbg',
#    'author_name': 'Mea Culpa',
#    'comment': "'Zelensky ke saath relationship mei hai Putin ki beti' then Modi saying -OMG. Damn funny. ",
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCL12D3roOfp7L1DUKDf2XSQ',
#    'author_name': 'The Indian Files',
#    'comment': 'I Started my Channel Inspired by you Sir ',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCDbg9ScK0Snko5l-hnyORSQ',
#    'author_name': "Andrew D'Souza",
#    'comment': 'You are a true patriot..all the best to you.. love yr vlogs.',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCzr-0yYBcuNMI8XGpg_zSvA',
#    'author_name': 'She B',
#    'comment': 'love ur show since few yrs...god bless u..',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC7hIq59YjpxBFy4diZsOnCQ',
#    'author_name': 'NIKKI 👸',
#    'comment': 'भाजपा के 8 साल जनता के 5 सवाल ?',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZrjLCFPw3X86itUhd0tW_A',
#    'author_name': 'Shakawat Ansari',
#    'comment': "Rip to sidhu moosewala ... He's one of a kind. ",
#    'published_date': '4 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZuwttyA2F-78A31smVSplw',
#    'author_name': 'xx Jack Sparrow xx',
#    'comment': "I'm so happy many people coming to realise about this useless BJP govt and what godi media is doing to the country",
#    'published_date': '19 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCjb4y2XXOXNjJzE-JXXFH_A',
#    'author_name': 'aditya singh yadav',
#    'comment': 'I want shah rukh khan to put a defamation case against whole media! ',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCjMKU3XyBOHRLA3upGfQhvQ',
#    'author_name': 'Hardik Sharma',
#    'comment': 'Satya the sharp noises you use , are very important for todays generation with major concentration issue to follow what you are trying to say. I suggest you should do a study where you do not use these and if the view rate decline ',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCwOW41CDbBVmymPp0Qx9QRg',
#    'author_name': 'aman khan',
#    'comment': 'We love our pm when he was cm',
#    'published_date': '2 days ago',
#    'num_of_replies': 6},
#   {'author_id': 'UCBRcVkCWmfLY1LOuDqws50w',
#    'author_name': 'Jit Mallick',
#    'comment': 'That kao kao and sabko pata hai was hilarious everytime ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCaKdzlclGoYTeo-bgUleOUw',
#    'author_name': 'True Love',
#    'comment': 'Its a humble request from me please keep updating such videos because people like me dont watch news channel because they are godi media . I just mostly saw your videos because they depict truth about the govt and news channel',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCBBc1K6i8tDmW-TVrsSvYzQ',
#    'author_name': 'Hasrat Bhanot',
#    'comment': 'In UK there is inflation, but UK govt giving subsidies in energy like electricity and gas by taxing big oil and gas companies, still this UK govt is a failed govt in many fronts',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC61RXor2Tk-Nv_R2PqnqZ9Q',
#    'author_name': 'Pallavi Tiwari',
#    'comment': 'I truly wish you should end up in a debate with these so called journalists..would love to see them getting a taste of their own medicines',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCRGIf6LxGGjAwhOba6qCM2A',
#    'author_name': 'Rishikesh Yadav',
#    'comment': 'when is see Sudhir Chaudhary pic anywhere : Is maamle me dono sampadak jail bhi jaa chuke ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UChICzH9llWkDS7m9L1YUV7w',
#    'author_name': 'Mukesh Raj',
#    'comment': 'Tihari be like :- Bas India ka media chutiya thodi na h Baki Desh ke media bhi honge ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCcpFa51vhUb1VZ79aMIuPgw',
#    'author_name': 'Vinod yadav',
#    'comment': 'Crow voice was funny ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCfDVfe2O-V8NgJCyoF6IsNQ',
#    'author_name': 'RAKIB HASAN',
#    'comment': '5:35',
#    'published_date': '2 days ago',
#    'num_of_replies': 2},
#   {'author_id': 'UCiIhXrY2uvMKt6L-Iu2agAg',
#    'author_name': 'Waseem Farooq',
#    'comment': 'Sir hats off to your efforts. Love you bro... Godi media is curse for nation.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCASXyigSviDWDvfS6cEXAHg',
#    'author_name': 'Dilbag Singh',
#    'comment': 'Sir your editing is next level ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCmjfrsB5fPjRvDfHVQG1CaA',
#    'author_name': 'A W',
#    'comment': "So according to AAj tak Russia Ukrain war is honour killing, Zelensky had an affair with  Putin's daughter; he staged war against Zelensky, and they deserve special award",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCoxwbF625ZfrBQ7Q7kdygJw',
#    'author_name': 'Mahammed Shihab',
#    'comment': '😁',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCit5nUarnnq8gW_9KQGkmJA',
#    'author_name': 'Osman official video',
#    'comment': 'One of my favourite Satya Sir Love you 3000',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCGJUyxphXVoA9CJxecTvleQ',
#    'author_name': 'Shahedeen Ansari 🇮🇳',
#    'comment': 'Satya bhai apki jitni taareef ki jaye kam hai ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC3Yd4PYRAwk8gcpDTgdgKAA',
#    'author_name': 'Humayun Ahmad',
#    'comment': 'When you played your love is gone on godi media it was so funny',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCLQAmC9Ce8mU3knWl-tl-kw',
#    'author_name': 'SALEEM Ahmed m',
#    'comment': 'If modi is really serious about beti padao beti bachao he would have stopped the hijab agitations as soon  as it was started.',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': 26},
#   {'author_id': 'UC2zRzFWVoNbQwSAjb_wl-SQ',
#    'author_name': "Ain'tMyself",
#    'comment': '3:40',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCjb4y2XXOXNjJzE-JXXFH_A',
#    'author_name': 'aditya singh yadav',
#    'comment': 'In foreign people have more spending capacity, less disparity more per capita income that why they are not much affected by inflation.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCafxMe52q0dMPS_x4u6IMZw',
#    'author_name': "Hafsa'z Kitchenz",
#    'comment': 'Love you 3000 Satya …!!',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCeyztjunCOCtmBVT4F5DrEg',
#    'author_name': 'Aftab Ahmed',
#    'comment': 'every Seconds I aM Smile ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCBu_PkAICtj9WrqQeCXTkhQ',
#    'author_name': 'sushil kumar',
#    'comment': 'ending "gaana laga de yaar" is epic',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC0T2man2TijgOeRGVJPhIPA',
#    'author_name': 'kushal khatiwala',
#    'comment': 'I am surprised why any neutral news channel has not contacted you for journalism ?  You are doing excellent work and keep on doing it...',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCaI-87PA1o31UE68tuKrRCQ',
#    'author_name': 'Girijasankar Mohanty',
#    'comment': 'Mr. Sudhir Choudjury justifies the increase in poverty in India as development.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC6qzv2FG0N2BtBmlUIAzuNQ',
#    'author_name': 'Rajiv Chawdhry',
#    'comment': 'You are doing a very fine job. Can you please share that graph showing 136 out of 140 episodes discussed Hindu Muslim?',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCuVF7xfZS8llOHfS3zJCgAw',
#    'author_name': '[INVALID ACCOUNT]',
#    'comment': 'Alright guys everything will be fine till 2050. ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCuIwOgJYK7KCmrcijwHV0ug',
#    'author_name': 'Nitish Kumar',
#    'comment': '2014 में आये थे एंग्री मैन अमिताभ बनके ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCah4LhGNc6KODCJiDtBd-DQ',
#    'author_name': 'Arif Khan',
#    'comment': 'Bhai satya bhai bohot maja lete hain yaar, matlab ek video nhn miss karta aapka. Great job bro.',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCFOBSnfkfvtr6uA88y8MZAw',
#    'author_name': 'pradeep shubakar',
#    'comment': 'Good statistics on godi , I see this episodes regularly,  funny as well real facts.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCO3SSIy8mMTOF5rWNwoo1vg',
#    'author_name': 'Abhi Sharma',
#    'comment': '03:59',
#    'published_date': '13 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCb6nk3_eGEqcLZ2QMn64WFA',
#    'author_name': 'Kaustabh Chakraborty',
#    'comment': 'I think you should have mentioned Newslaundry when telling about the debate stats of the media channels.',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCwWDcgi9OtyEDFOCPmYuawQ',
#    'author_name': 'Aviral Singhal',
#    'comment': 'Power of money. Aryan khan is clean. ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCAPsjC6FPOUyz8mkpbK_x1w',
#    'author_name': 'sanjeev sahu',
#    'comment': 'Aryan Khan in thumbnail',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCQzmfHHY7abViwXxC4SFSKw',
#    'author_name': 'vivek singh',
#    'comment': 'You are doing great job satya bhai.',
#    'published_date': '12 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCwujNBKc4ZY97ndOlBLZ14Q',
#    'author_name': 'Rigzin Angchok',
#    'comment': 'Chicha the DON',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCAoUj-z9y9xcw4q9-sREKGA',
#    'author_name': 'विपिन यादव',
#    'comment': 'It’s rare talent to make master video every time',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCKmoDxoby7QgAnIQORVVKPg',
#    'author_name': 'zeeshan khan',
#    'comment': 'You should add Wion to the list',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCrjDKCyK71ar3BZ2A0W6BzA',
#    'author_name': 'AKSHAY GANESH',
#    'comment': 'Zelensky one was hilarious',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC1lLLu-aFl1haL7t07TvKWQ',
#    'author_name': 'Nafis Choudhary',
#    'comment': 'gullu or CROW ki ladai',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCwm5d6xC5eZl9pLDTbOZzMg',
#    'author_name': 'Football & Mobile',
#    'comment': 'Right answer US facilities much more development and privilegethan here in INDIA,more job more opportunities,higher income rate.',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCW4jhlyTf0qrAo_g_er334g',
#    'author_name': 'Roxxy World',
#    'comment': 'Its time to Ban Godi media from peopels heart...',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC3vZpg9lsWvddnKIlXyiFOA',
#    'author_name': 'Md. Jahidul Islam',
#    'comment': 'I want congress to come in power just to see how these godi medias operate in the changed regime. 😐',
#    'published_date': '2 days ago',
#    'num_of_replies': 13},
#   {'author_id': 'UCnHRyoQF2vgHvg1QeHa4V2A',
#    'author_name': 'Amol Jadhav',
#    'comment': 'You should thank newslaundry and peeinghuman for the data.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCtAV2cdqGM550qYLzYbt4ow',
#    'author_name': 'Mohammed Shaik',
#    'comment': 'You are doing a good job bro...',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCzr-0yYBcuNMI8XGpg_zSvA',
#    'author_name': 'She B',
#    'comment': 'gullu and arnab have a competion in barking 😂😂😂',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCEVQcHnMX_KT0ESEn09-HVw',
#    'author_name': 'Praveen Kumar',
#    'comment': 'Godi media: Jan srokar ke mudde! Ye kya hota hai?😂',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCxEFH1VLFHLugvGPTNwj-Lw',
#    'author_name': 'Surajit Gharami',
#    'comment': 'Nobody noticed that in this video at ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCKqVOxAEYxrgkamlGSxKEdw',
#    'author_name': 'abhilash singh',
#    'comment': '09:30',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCDKRYK5lqpJyvRnEdQgf-kA',
#    'author_name': 'Dr Mohammed Kaif',
#    'comment': '8:29',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCzOUGEZwQ9JnQ5xHXNZ19DQ',
#    'author_name': 'MD Murad Hussain',
#    'comment': "Generally i don't watch news but i watch your every video becouse you cover all the news so funny way .",
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCxMiqCaijazfYh71BXB-HEg',
#    'author_name': 'Aditya',
#    'comment': "They follow Shri Ram, Ram follows Dharma, Dharma tells you shouldn't differentiate between anyone, where are we going? ",
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UC-IedOOc9-EqaQ6iIXBGfsA',
#    'author_name': 'Yash Pal',
#    'comment': 'Satya bhai aab shorts bhi dala karo na.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCAjWfnR6Z-B0P-F770O4PyA',
#    'author_name': 'Vishwas Pratap',
#    'comment': '1:29',
#    'published_date': '19 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UC5_Yoxdy4PALzZSjI5wqRBg',
#    'author_name': 'AA',
#    'comment': 'Plz be in good health .....seeing ur videos our blood pressure and sugar are under control.........👍',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCgtpxI_P7wNjDjBNTGtc1Jg',
#    'author_name': 'Swarnadeep Ghosh',
#    'comment': 'Also modi ji stand against godi media 😊🙏🙏',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCt0Vodmdv-NM5cQj2WnXtfA',
#    'author_name': '_khansb_writer',
#    'comment': 'You nailed It BRo 🤣🤣🤣',
#    'published_date': '17 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCedqCP5Un9R7f0k2HyHXBAA',
#    'author_name': 'Mihir Shahi',
#    'comment': '(At ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCemEEOtt2HUUkV0r0ZyZp0Q',
#    'author_name': 'Mohd Mansoor Alam',
#    'comment': 'Love you Satya bhai💪🏻',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCnHJL9KYTu4bpt4Ce0isqvg',
#    'author_name': 'Kuldeep Singh',
#    'comment': 'Satya , the time when people use your meme .now you are using their meme.',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UC5xvlXwRe77CVMM7fSPM-dw',
#    'author_name': 'Kanika Paikara',
#    'comment': '8:41',
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCZT8AvTHqlySdV0R6J4bQeg',
#    'author_name': 'Engin Altan Düzyatan',
#    'comment': 'tihadi',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCt0987uCJUKw9RZcJwNRD2A',
#    'author_name': 'J D M',
#    'comment': 'Hilarious ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCAjWfnR6Z-B0P-F770O4PyA',
#    'author_name': 'Vishwas Pratap',
#    'comment': 'Good job bro ... Keep it up and be safe',
#    'published_date': '19 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCB6WIZzzDzPdchwugn4MXrQ',
#    'author_name': 'Shashank Rajput',
#    'comment': 'Dr Hathi Says After Watching This video Sehi Baat Hai 100%',
#    'published_date': '2 days ago',
#    'num_of_replies': 4},
#   {'author_id': 'UCOfT7n2PnKiLGuAZV4dGRxQ',
#    'author_name': 'Sachin Singh',
#    'comment': 'Although I never agree with tihadi but there is inflation all over the world....have some sense satya.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCNl0dA2kGbvpkhN1vtzHsUQ',
#    'author_name': 'Mounica Mona',
#    'comment': 'We as middle class family is suffering so.... much... ghar May kuch acha cook kar ni ki liye bhi soch na partha hi.....',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCeR97nAonDp2SsQ5QSdg6fw',
#    'author_name': 'Shivam Upadhyay',
#    'comment': 'अबे तिहारी जिन देशों में महंगाई बढ़ी है वहां की प्रति व्यक्ति आय भारत से कई गुना ज्यादा है समझ में आया chuतिया',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvsUOiQLVSjXHpMA1RwC8Lg',
#    'author_name': 'Jᴀʀᴠɪs🔥',
#    'comment': '8:13',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCPEjWbQQhp55WdXG-ZBRb3A',
#    'author_name': 'Manoj Pandit',
#    'comment': 'Studio changed ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCAMPBSAfvqv0-6MBQp_2gMg',
#    'author_name': 'SUPERHERO bandaa',
#    'comment': "''Thori maryada rakhye.''",
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCubb4dpVjaQGoDz7WVBadJg',
#    'author_name': 'Sylvum',
#    'comment': 'Jo bhi subscribers hai is channel ke',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCi0YTmYuJKUKwdkKBSeR5iA',
#    'author_name': 'Sujit Pawar',
#    'comment': 'Talk about Indian educational system first of all in Maharashtra',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCuPVXz_zzgNd1gUAJOKUdag',
#    'author_name': 'Vikas singh Maravi',
#    'comment': 'सबरे राखचस हो gye हैं राख्चस ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCcWXdbq2uYd5gfxTTrYoh0Q',
#    'author_name': 'Mohammad Umar',
#    'comment': 'First like then watch. I am addicted of your videos.',
#    'published_date': '15 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCejMLtUXbidqh18EmLqFl1A',
#    'author_name': 'ABDUL KADIR Khan',
#    'comment': 'Majaa aagaya brother, kiya analysis kiya. ',
#    'published_date': '5 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZtZmqBqEp2_BJP_PdVyxEg',
#    'author_name': 'Yashmit Gupta',
#    'comment': 'satya bro why u always say media is becoming bekau for us u are the main media and u are not bikau actually one of the best .',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCpa-McNDiccBULcaISJl_rw',
#    'author_name': 'abhishek pandey',
#    'comment': 'So just tell me the honest mahaan liberal media person ,,why opposition settled only in three states states. What about laudagathbandan in 2019',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCSuCazzjljraArJsisBcXZw',
#    'author_name': 'Bipin Kumar',
#    'comment': 'जापान से हमारा पहला परिचय उन्नीस सौ तिहाड़ी में हुआ था।',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCPM57BrVsGB-KhS06n8poEg',
#    'author_name': 'kabaddi lover',
#    'comment': 'First comment love from punjab',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCQR4AmkRMJSEGISVGvzOeQg',
#    'author_name': 'Devesh Pal',
#    'comment': 'Attendence please: ',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCrjRZqGOQi06qy00oBQ4NDQ',
#    'author_name': 'RATAN GARG',
#    'comment': 'Great job bro ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCXSnMLu_uVW_RWYrd15rNOA',
#    'author_name': 'Deeptanu Choudhury',
#    'comment': 'Please make a video of Ex Chief Minister of Tripura (Biplab Kumar Deb), He resigned due to some unknown reason, but some news channels shared that he caught red handed asking for 06-07 cr from a contractor.',
#    'published_date': '5 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UC0teDiovLmXb4K6GQ1dOc0A',
#    'author_name': 'vibha sharma',
#    'comment': 'Make one video on Good Journalists to honor them',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCdLFYEYod6qiq2Gttp5WB_A',
#    'author_name': 'Archana Yadav',
#    'comment': 'Congratulations sir Ravish kumar n kl k prime time m apke show ki tarif ki h............ Bt u deserve much more',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC4Nh4KT4C0BeO7H50yHH2PQ',
#    'author_name': 'Subhajit Bhattacharjee',
#    'comment': 'I m from Northeast but you will never say anything about the development going after Modi Govt came to power. Dukaan toh aap bhi chala rahe ho bhai.',
#    'published_date': '1 day ago',
#    'num_of_replies': 1},
#   {'author_id': 'UC8cAxJ-a8wWWyMwnJ48eprQ',
#    'author_name': 'H2so4 • H2o',
#    'comment': 'Never old.....is mamle me dono sampadk jel vi ja chuke hai',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCrVEiyOLOBeSzQJZBtjizzw',
#    'author_name': 'parvin sultana',
#    'comment': 'You kept  thumbnail of Ariyan bcz of viwes ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCxMzkoFSdDACFS44OMncdzw',
#    'author_name': 'sameer gaming',
#    'comment': 'Good Job Sir ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCofh04yE152rg-GAu0zcpDg',
#    'author_name': 'A K Sharma',
#    'comment': 'Epic video bro . Keep it up.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCSJI2O1krOY1qbPFUlN7rvw',
#    'author_name': 'shammi1960',
#    'comment': 'अक्षय कुमार: अबे ओए इधर उधर ना देख ना कर खाने की बात ऊपर देख डॉलर ऊपर जा रहा हैं, कैमरे से नज़र हटा',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCn2sq0WjB2nrv-K50GEyK8w',
#    'author_name': 'Bravo Charlie',
#    'comment': 'dont get distract from original issue , need to bring Nirav Modi and Mehul Chowksi back to India , politicians trying to distract us',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZJ5-OUiKFtdRulrD2ZW6pA',
#    'author_name': 'Neal Kedari',
#    'comment': "Satya please dont watch godi media's channel  you're increasing them TRP ",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvXtw3BvIR2Vi3TCGECVG7Q',
#    'author_name': 'Ritik Rana',
#    'comment': '7:45',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC0Ht7kJK2B54ZdpZSD2mgjQ',
#    'author_name': 'Mohd Shakeel',
#    'comment': 'You laugh very well sir',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCUxlU-l_wT_StPSpVAfYOOQ',
#    'author_name': 'shiku',
#    'comment': 'Best of luck ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCtlGErN0t6VesBNPNRqZ4Rw',
#    'author_name': 'Kitty Candy',
#    'comment': "American citizen are secured by minimum wage ($15/hour), we don't have it here.",
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCfoGV5Sj-pBJcdnvebhoAUA',
#    'author_name': 'Prince Alam',
#    'comment': 'Love uhh 3000 brother love from bihar',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCAOZPUiCbIyS_3wjV9xzjQw',
#    'author_name': 'Pratham Sharma',
#    'comment': "Modi's oh my god ",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCdiZlDvuUT5UvVmHoFmEU2Q',
#    'author_name': 'renu verma',
#    'comment': 'Godi media : ',
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCkavQUdxJPgdYL_8G9yTb7A',
#    'author_name': 'Jas Singh',
#    'comment': 'what ever you do but people want still BJP look in UP',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCJ3nONCjvQmvd5NKUtm16Lg',
#    'author_name': 'INSAN POLITICS',
#    'comment': 'Your intro is amazing',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCs8N5D3XzWJy_psz-PaywRA',
#    'author_name': 'Wahid Educare',
#    'comment': 'Bahoooooooooot achha bhai i salute your courage for exposing godi media.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCaApy2VOND05zrUz7Gr18xg',
#    'author_name': 'ranjeet shakya',
#    'comment': 'Tihadi be like : bharat m garmi kha pad rhi h ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCerm4sWBb_4wdUbBOsWMNIQ',
#    'author_name': 'हर्षित चौहान',
#    'comment': '#BanPFI',
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UC4UolUjZpKVnR83yNGkxwOQ',
#    'author_name': 'Darpan Sayam',
#    'comment': 'Love is gone',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCuUlejqeSpf_sCWHefKB9gw',
#    'author_name': 'Saurabh Maheshwari',
#    'comment': 'Aaj Tak ne decode kiya real reason behind Russia-Ukraine War',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UChcM1u3KsjyLc4P2hjfDDVw',
#    'author_name': 'सौरभ आदिवासी',
#    'comment': 'Great work sir',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCj0y3imxLbtIYzv1-1-m0Rw',
#    'author_name': 'Ashwini Gawai',
#    'comment': 'Very good bro. ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCUXhkq1iN8AnfhV-sZdGx3Q',
#    'author_name': 'SANAUR RAHMAN vines',
#    'comment': 'Pawan khera nailed gullu',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCRS_uUpBrEkK9_H4vIVnuOQ',
#    'author_name': 'Shoaib Khan',
#    'comment': 'So ironic that Kailash parvat where Shivji resides is captured by China and these people are trying to find Shivling under Taj Mahal',
#    'published_date': '2 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvYxYUPAr8vfrUMT9oGIC-w',
#    'author_name': 'Daniel Danger',
#    'comment': 'i am a bengali. in west bengal economy has collapsed. islamization of bengali literature is going up. now u people decide about your future.',
#    'published_date': '5 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCXbDL_7p3YVj6NmcK6OpE6g',
#    'author_name': 'Syed Mubarak',
#    'comment': '5:05',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCD3zWjKcmSfvKkxpOrNxhiQ',
#    'author_name': 'videoadda',
#    'comment': 'Tihadi ne sahi to kaha, mahgai kaha hai kahan hai according to tihadi, pakistan , Shrilanka or America main hai mahgai,',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCpDQRf1aAtoQ8wF4Z4JId2w',
#    'author_name': 'VINESHV',
#    'comment': 'For Media from Modi ji',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCrknPx_y8JsRbnVf-oGnHMQ',
#    'author_name': 'Zaid Shaikh',
#    'comment': 'Love you 3000 Satya bro ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCl9iXw6Otmuahot33kwrW7A',
#    'author_name': 'imran lion',
#    'comment': "Sir you always talk about Kashmiri pundits but you don't talk about Kashmiri Muslims",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCHoHlc0DvFpQsSsfgXOITfA',
#    'author_name': 'Amit Purohit',
#    'comment': 'Acha words lekar aaye aap jaise',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCrTWseXyWnROKm9t8VM8ymg',
#    'author_name': 'A2Z Fights',
#    'comment': "I see day by day Tihari's analysis is touching rock bottom. How hard is trying to consol public by comparing with other country. Aisa hai agar padosi k ghar me Roz fight ho rahi hai to hum apne ghar me ho rahe fight ko justify kar sakte hai.  ",
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCj17cpkMBzYSyorNL_iT_gA',
#    'author_name': 'Robin Frost',
#    'comment': '"yeh hamara media" Aisa kaise. ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCah4LhGNc6KODCJiDtBd-DQ',
#    'author_name': 'Arif Khan',
#    'comment': 'Jab wo "Dalaal" word peeche se aata hai to bohot maja aata hai.',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvWwjwdGti2e-JBp5M04Aow',
#    'author_name': 'gagan singh',
#    'comment': 'Oh my god 😂😂😂',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCX5GsC7MtDF9rBjjyw7_goA',
#    'author_name': 'Saurav Kumar',
#    'comment': '8:30',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCk3mNPljKUafvVKaMOQfB5w',
#    'author_name': 'Straight Talk',
#    'comment': 'Purpose of chaddi gang sarkaar is served in any case.  With the help of godhi media they kept bhakts on a high and busy for weeks on end spewing venom on channels.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC3VLfFf96uujjNLsKc4TM4Q',
#    'author_name': 'aziz ahmed',
#    'comment': 'Covering up nahi, Satya. Galat meaning deta hai. 👍',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCaW8q5ppmdVfUVBv8kpvLeg',
#    'author_name': 'Gagandeep Singh Uppal',
#    'comment': 'Keep up good work',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCupSMK4V-Ei8YgQN6dQGHcA',
#    'author_name': 'SizaN is here',
#    'comment': 'Bhai tera 1M subscribers kab hoga??  6saal se tere sath ho Satya Bhai',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC2WajIBw0YzbJ45GqQO0_Dg',
#    'author_name': 'Prathamesh',
#    'comment': '9:15',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCdDJoUp8tGfSGd42yPIc8Rw',
#    'author_name': 'Tanaya Amar',
#    'comment': "The Zelenskyy thing is such fake news. The husband/partner shares his last name with Zelenskyy, they're not the same person ffs",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCM7J-L9qN-3poINgCgYzHpg',
#    'author_name': 'sumit Kumar',
#    'comment': 'Awesome job bro',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCDNC-yFuXcYr-p7a71TSjTw',
#    'author_name': 'Abid Khan',
#    'comment': 'Nyc videos brother😍',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCohU6E8GPejUS0tEz7Q3zpw',
#    'author_name': 'nazia hasan Hasan',
#    'comment': 'Bhai tihadi America ka living standard and quality of life dekha hai ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCm4aSImUGH1jh6Fs22YBRmA',
#    'author_name': 'Aryan Pandit',
#    'comment': 'धर्म का नशा उतरते ही श्रीलंका की जनता को एहसास हुआ की वे बर्बाद हो चुके हैं',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCtNWJR_1rADL5URTjOzvSbQ',
#    'author_name': 'Raju',
#    'comment': 'SATYA SE HEART MIL JAYE TOH MAIN PAGAL HOJAU !!',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC2HrjAvS_9ocQhS3_vVbrVA',
#    'author_name': 'Azhar Mehmood',
#    'comment': "I m muslim  a muslim  can't live without kashmiri pandits bro this is not online support just like shown by BJP workers",
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCfs6GxEIlcaS52MbMw5cs3Q',
#    'author_name': 'World 🌍',
#    'comment': 'Robindronat takur also visited Japan long time ago.',
#    'published_date': '14 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCnl8X5TVjnN-U2GS1VskPlA',
#    'author_name': 'Tom Codm',
#    'comment': '7:05',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC-bLF-L1KY9Mj_XJayChd7A',
#    'author_name': 'Deepak Yadav',
#    'comment': 'Good job brother 👍👍',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCGl2oMNOM_YWRUVE2T5g-bw',
#    'author_name': 'мани',
#    'comment': 'Love from Amritsar❤',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCnez8BS8gtR1qWZq02vvn-g',
#    'author_name': 'SHAILENDRA KUMAR',
#    'comment': 'That s why we going down in press index',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCYwGFSL0064z0uZMwUHaDqA',
#    'author_name': 'Shakir Hussain',
#    'comment': "Chicha's OH my God is new trending",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCjP0AK-Igtp0S0PgTrLGrJA',
#    'author_name': 'finance guru',
#    'comment': 'News channels nowadays has become comedy channels with baseless and fake news..',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCU6kLZaS2UaJlcfvfhxiMZA',
#    'author_name': 'FAKRUDEEN',
#    'comment': '❤',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCPc2yjPAo94w2VyH420Xh2Q',
#    'author_name': 'anjali saini',
#    'comment': 'sir please tell tihadi that they earn money in doller not in rupees. please tell them',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCBYmTJWTuPk1nTYlONAU_8Q',
#    'author_name': 'shubham rana',
#    'comment': 'Oh my god ',
#    'published_date': '18 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UC6CYY-Tm-IGyxRowRD9WBHQ',
#    'author_name': 'ajinkya aherkar',
#    'comment': 'Good work man',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC_cuG3i4jyNvwjOosOvaJcQ',
#    'author_name': 'harsh valvi',
#    'comment': 'Godi media is our new entertaining spoofs..',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCU5ViEp8cE6k7tlF58qjwGg',
#    'author_name': 'Ruma Gupta',
#    'comment': 'Good job with humour',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC9BrHqKe19RytDO5QeKP_QQ',
#    'author_name': 'aamir sid',
#    'comment': 'Ek baat puchhu??',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UClZIPuVCoMGx5rRvw3FzuaQ',
#    'author_name': 'Ritika Bhardwaj',
#    'comment': 'Khairr ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCjlMuDgqXoPXR2DqLfpGReA',
#    'author_name': 'Ankit Gautam',
#    'comment': 'तिहाड़ी कुछ पढ़ के आया कर। 1942 में सुभाष चन्द्र बोस जी ने आजाद हिंद फौज की स्थापना की ओर 1943 में जापान गए और जापान के PM तोजो से मिले',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCxUz2vPjsxRJ1pDDJWS-DPQ',
#    'author_name': 'Rupinder singh',
#    'comment': 'Keep it up ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC6jcSuZTWM7wgw8Xl8qmnpA',
#    'author_name': 'Gautam mehra',
#    'comment': 'I am not highly educated and people feel most of my comments are sense less and illogical.',
#    'published_date': '15 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCdJTJlOult66cZpDSLrTOKg',
#    'author_name': 'Ayush Arya',
#    'comment': 'Agree bhai ',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCWl0F0co0O-msUHQCTOfmlQ',
#    'author_name': 'JOKER GAMING',
#    'comment': 'A sampadak Dhoka dhadi ke case me tihaad jail ja Chuka hai..',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCEUQY63UQJNNqbfPeATxSfA',
#    'author_name': 'aa k',
#    'comment': '1:29',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UClbIeOYkOPhm53jtWmyzhoA',
#    'author_name': 'Waqar Ansari',
#    'comment': 'Aakhir mein"GANA LAGA DE YAR"',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCBQZ-FzT78ATeXdk8zveqPw',
#    'author_name': 'Samir Bhattacharya',
#    'comment': 'Watched this one and finally unsubscribed. It was long overdue. You used to be funny and neutral. Now, you have become one-sided and sooo monotonous.',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZOxU38lIG6vHc3-gz8J6zQ',
#    'author_name': 'I M mallick',
#    'comment': 'O my god',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCXTI7Hlb3fh7IGQy39P5zsg',
#    'author_name': 'Vivek Kumar',
#    'comment': 'Baudhishm was the one of the first relations between India and Japan jab Bhagwaan Bhudh ne Bhaudism ka vistar kiya ye to Bacho ko v pata h in bhadwo ko kaise nahi pata kya hi Hindu h ye ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCK1V3HvBfNItuISdcIS3XTQ',
#    'author_name': 'Zain siddiki',
#    'comment': "Bhai, why didn't you cover Aryan Khan's topic? You have mentioned his pic but no news about him.",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCiWi-LM_V1chbA-YpfichmQ',
#    'author_name': 'DocTravel',
#    'comment': 'All right guys...❤️❤️❤️',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCUx5OecXijuqIf7H-pIIUEw',
#    'author_name': 'Meraj Khan',
#    'comment': 'Boss you are too good 😊',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCVt4lIC99YFBM5GFmIxuR6w',
#    'author_name': 'ManoJoy',
#    'comment': 'Tihadi ko mehengai isliye nahi lag rahi hai kyuki uske pass 100 crore hai na 🤣',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCLNBfwAWbpE5VeSeRRzaLwQ',
#    'author_name': 'Gulam Mohiddin',
#    'comment': 'Modi ki local media se hi phat jati hai to international media ko thodi jawab milega? OMG bolke nikalliye lol.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCD5fwiMCLzYe5Owy2TCk0Ng',
#    'author_name': 'Syed Rizwan',
#    'comment': 'TIHADI AUR GODI MEDIA KA MUH KAALA HO GAYA ',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvZDA0LNnIWuUtUXliMJhpw',
#    'author_name': 'Sayed Sagir',
#    'comment': 'Modiji,,,,,,  ye jhoot hai jhoot hai jhoot hai, Ye sab kahan se dhoond ke late ho bhai, keep up the good work.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC5UvVJdOCyzvNfkci-FhffA',
#    'author_name': 'Time pass',
#    'comment': 'Never ever give up',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCCfr2hZ_F9YG8pXDPw2_5RQ',
#    'author_name': 'Srv',
#    'comment': 'Act of shameless!!',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZRsgcu_4fJnuChq_9WY39Q',
#    'author_name': 'Roof Sat',
#    'comment': 'Replay button 🤣 - ',
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UClXCsUSDNUB9u1fBVxmNGbQ',
#    'author_name': 'Ashik Hossain',
#    'comment': 'Good comparison with godi media. "Main to yehain haagoonga"',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCfjwRoP4caKpAunBf6APreQ',
#    'author_name': 'Smrutimayee Mishra',
#    'comment': 'Gullu ,tihadi modi ki beti ,,really they r shame on nation free media..',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UC8kRSTKW5r_YVwTmy4ak93Q',
#    'author_name': 'edwin nadar',
#    'comment': 'Better to avoid Godi media what else we can do....',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCdLtKLSWiYdKklLXoRI4uog',
#    'author_name': 'Nature lover',
#    'comment': 'Soon our family members will 1 million',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC-x-gwM-Df9eALE4furzxrg',
#    'author_name': 'Imran khan Editz',
#    'comment': 'क्योंकि इस मामले में दोनो संपादक जेल भी जा चुके हैं।',
#    'published_date': '1 day ago',
# ...
#    'author_name': 'DJ Fred J',
#    'comment': '7.05  Tihadi chu tho tu hai',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCBGML6wdXZBMoZM92k7UVrA',
#    'author_name': 'Deepanshu Maurya',
#    'comment': 'Second view',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCD5fwiMCLzYe5Owy2TCk0Ng',
#    'author_name': 'Syed Rizwan',
#    'comment': 'GULLU K DIMAG M GOBER HAI',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UChG7-cFY-ShF8I56S1HlWWQ',
#    'author_name': 'Mothman¹⁹⁴⁷',
#    'comment': 'Aur bhai kabhi tho acchi baat nhi karliye kar har bar congress jaisa Banna jaruri hai kya',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCYSZiIyqlkP1sVua053zukA',
#    'author_name': 'Rabbani Ali',
#    'comment': 'Godimedia dekhnay walay sabsay bada chotya hai.',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCOKFpnw33N3rGej7LE2r-kw',
#    'author_name': 'abhilekh bagade',
#    'comment': 'तो करना 😁😁😁😁😁😁😁😁😁😁😁',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCVXMnFzQURhAs_B1tXdYMeA',
#    'author_name': 'Salman Khan',
#    'comment': 'So sad ...',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCPh9sPGxbJwA0-t2VT0PO7w',
#    'author_name': 'Mohd L Ali',
#    'comment': 'Savitha Bhabhi In Background',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCYsR_K1GheDC2qpFLP4Lh4w',
#    'author_name': 'contender_micheal',
#    'comment': 'Op🤣🤣🤣❤️❤️❤️❤️\U0001fae1\U0001fae1',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCRoQ7msifzPcPeLxV4PDSPQ',
#    'author_name': 'shadow',
#    'comment': 'Brother please raise issue of punjab laborer strike in punjab .......they are very poor no national media is covering them.........please',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCsJsGQp1X_f8EaX27qyt3Rg',
#    'author_name': 'Sanjay M Garpade',
#    'comment': 'Is mamale dono sampadak jail bhi ...',
#    'published_date': '22 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvXtw3BvIR2Vi3TCGECVG7Q',
#    'author_name': 'Ritik Rana',
#    'comment': 'Bhai sirf godi media ki ku baat krte ho...',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCWXgswwwr16tD2K-MTk-sHg',
#    'author_name': 'Rajesh Bhanjan',
#    'comment': 'NCB National Corruption Bureau',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCGJmFTjkFM9FdB6QON4TSBw',
#    'author_name': 'Sharayu Vikram',
#    'comment': 'Leave it Satya',
#    'published_date': '8 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCiPQJgQztx-o9RJk-esuiew',
#    'author_name': 'Dharmendra Singh',
#    'comment': 'Satya ji apke piche Gandhi ji ki cartoon photo h we hataiye',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCL6vAr09vb2310OWbYiHaxg',
#    'author_name': 'rihaan khan',
#    'comment': 'Bhai chutiya media hatou desh bachou....',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCTTd87DL2A73yn97yeiaS4A',
#    'author_name': 'the satan',
#    'comment': 'man try to improve ur mic',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCidDOvzCytWIdaH2N-G3P1g',
#    'author_name': 'Bijay Tanty',
#    'comment': 'Good',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCsYaNPXD-Op5Pc1BhXtVohQ',
#    'author_name': 'md azzm',
#    'comment': 'Aur is mamle me dono sampadak ___________?',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC_cTjeMtWJxbnTdvRPVeN5w',
#    'author_name': 'salim gani',
#    'comment': 'Medi news channel ko koi bhi nahi dekta hai',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCiqSyv5gHO-og1UXl2vWtjg',
#    'author_name': 'Atul Yadav',
#    'comment': 'gullu is an anchor not journalist',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCYBY1NnYYi4m5OPtI60oXMg',
#    'author_name': 'Satyam Singh Gurjar 999',
#    'comment': '😭',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCwXfo9_l-hHDt4ADyUd5U8g',
#    'author_name': 'Saleh Ahmed',
#    'comment': 'Is mamley mei duno sampadak.........................?',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC8xNZTlTAKDx7nc23HI5pjg',
#    'author_name': 'Ravi Prakash Maurya',
#    'comment': 'Bhai inta इंतज़ार तो मैने अपनी gf ka nhi Kia jitna tumhre video ka karta hu',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCQe9RSZRgU-BR8ZVNVFJipg',
#    'author_name': 'Ronak shah',
#    'comment': 'Top viewer',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC_cSHcHEMHrY0JG9oOkoi7w',
#    'author_name': 'Arvind Kumar',
#    'comment': 'Isss msmle me tihadi gu.. kha chhka h',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCWmBeyyBRMM8qscY5H8VquA',
#    'author_name': 'ꜰɪᴛʙᴇᴀꜱᴛ ᴢᴏɴᴇ',
#    'comment': '#ʙᴀɴɢʜᴏᴅɪᴍᴇᴅɪᴀ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCKJt-MfyT6Fe2ritQzG_BGA',
#    'author_name': 'Imo. saifi',
#    'comment': 'Song MST hai ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCyUjTFa70ZF2nX7YI7HcBhg',
#    'author_name': 'Kunal satapathy',
#    'comment': '#boycut',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCRoQ7msifzPcPeLxV4PDSPQ',
#    'author_name': 'shadow',
#    'comment': 'Brother please raise issue of punjab laborer strike in punjab .......they are very poor no national media is covering them.........please',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCgPT6Gbf6BWTq3t08B8sWPw',
#    'author_name': 'Manjinder Manjinder',
#    'comment': 'ਗੋਦੀ ਮੀਡੀਆ ਦੇ ਚਮਟੇ ਤੱਤੇ ਕਰ ਕਰ ਲਾਵੇ ਪਿਛਲੇ ',
#    'published_date': '13 hours ago',
#    'num_of_replies': None},
#   {'author_id': 'UCbCYPmEyutMWUkIVJB0kaCQ',
#    'author_name': 'Bhaawesh kumar',
#    'comment': 'Buddha ke time se rishta h japan se',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCHuoCchLZguKsUPCnAdm4pQ',
#    'author_name': 'Pradeep Sharma',
#    'comment': 'Mst',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC65ldfuA4Xu_S5IhrUf7oWg',
#    'author_name': 'Ataur Rahman',
#    'comment': 'Bhai mere aryan ka photo lagaya hai es pe baat bhi krna chahiye tha',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCLu51Wmemdb0w4mjNWvImsA',
#    'author_name': 'Amit Kaushik',
#    'comment': 'Frustrated guy just wt ex muslim movement of india.',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC6pcQOI6DZkTlsjq2eLMAaA',
#    'author_name': 'Arkaprava Paul',
#    'comment': "People don't give a fuck...they are busy earning money to pay for ROTI, KAPDA AND MAKAAN. OHH BHOOL GAYA PETROL, SABJI, ZONDAGI, MAUT AND WHAT NOT ",
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZqnFx88UymmtTq5I4z2K1A',
#    'author_name': 'Dhruv rathee today',
#    'comment': 'Why you changed your background',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCY-KU7_yWDFTTmD1HfO7Hfw',
#    'author_name': 'BREAKING NEWS.',
#    'comment': 'तिहाडी तिहाडी तिहाडी',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCLTOvpJwBgR6Ii5LdrHmzhw',
#    'author_name': 'Saiqa home',
#    'comment': 'Sb darood shareef parh lain',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZ6wj7tVMEujmwyE49dbkYw',
#    'author_name': 'Raman Arora',
#    'comment': 'Ye channel modi khareed chuka hai, pata nahi lagta aapko ? Wo paise deta hai khabar ki tarah uski advertisement ki tarah dikha di jaati hai',
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCHhUWbgWF2zab-fCP8K7URw',
#    'author_name': 'sid',
#    'comment': 'Sala feku',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCLTOvpJwBgR6Ii5LdrHmzhw',
#    'author_name': 'Saiqa home',
#    'comment': 'Tamam dost namaz main pabandi kare',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCa0z7i0gc0XK3U4qGib-0vA',
#    'author_name': 'Kb Khadka',
#    'comment': 'Im the first viewer',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCwAB2o-M9abHdzhmAOhYNdg',
#    'author_name': 'Lonely Life',
#    'comment': '🇮🇳',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCaKITmHs8GggDoiXhjvdzJQ',
#    'author_name': 'Gyan world',
#    'comment': 'Ha mared all world me mangi hai',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCHuoCchLZguKsUPCnAdm4pQ',
#    'author_name': 'Pradeep Sharma',
#    'comment': 'Dumdar',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvJGsh40Hu0e34XIbBrXFOQ',
#    'author_name': 'Mdrasheed Qureshi',
#    'comment': 'Cointeno Cawa Cown Cown',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCbfxSh_ncv5oeJvSc2LfP0g',
#    'author_name': 'Anuwar🦋Gaji',
#    'comment': 'Kau kau ',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCQkv_a85AOw9R3ls_-Z7mlw',
#    'author_name': '아인로미',
#    'comment': 'Hum 145 comments mai hai. 🤔',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCxLDbgKM9pZSCoKqed6TP8A',
#    'author_name': 'Armaan Bass',
#    'comment': 'Mahangai to itna km hai ki mera jhaat v nhi jal rha',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC3_2qiyBsqveyxi8A_cxIkA',
#    'author_name': 'Shaik Saleem',
#    'comment': 'First comment',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UC6OEU2D5RdNRAe5XpFaWpKA',
#    'author_name': 'Jafar Sadiq',
#    'comment': 'Gullu tuhllu bhokana hi janten hai kat',
#    'published_date': '1 day ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UCUyBlam93xieCTEXQ80YyZQ',
#    'author_name': 'Rajesh Paswan',
#    'comment': 'जी न्यूज बिकाऊ चैनल है!',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC2NVvUlyq9p2WjHDxXxv5zw',
#    'author_name': 'aadi manav',
#    'comment': '🤓😎🤓😎🤓😎🤓',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCLTOvpJwBgR6Ii5LdrHmzhw',
#    'author_name': 'Saiqa home',
#    'comment': 'Sb 1st kalma parl lain',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCD02OufyMWey97T1i3dTGZA',
#    'author_name': 'Farook mansuri',
#    'comment': 'newslaundry ka nam lo waha par',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCNqEkZZTbUPAu097_flwPvA',
#    'author_name': 'Stay Tuned with Akash',
#    'comment': 'मैं आमलेट खाऊं गा',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvK-kGhvXOZiRyjLwxm-khg',
#    'author_name': 'ThundeRxDraGon ♪',
#    'comment': 'bhai log Isse week ma 1 million karwa do',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCu4K2rVFRtJVjJy9ayh656A',
#    'author_name': 'GAURAV DHEBAR',
#    'comment': 'Kashmiri pandit murdabad What about Tamil refugees from last 32 years Shame on all',
#    'published_date': '2 days ago',
#    'num_of_replies': 1},
#   {'author_id': 'UCtU0huBgJh0HXlNX4ylaaxg',
#    'author_name': 'Shridip Khadka',
#    'comment': 'First',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCfszrpi-5SEAWwsxKsz4oLg',
#    'author_name': 'Zehar Gaming nk',
#    'comment': 'Bhai kuch parivartan toh ho nhi rha kya fyda yar band kro ab\U0001f972',
#    'published_date': '2 days ago',
#    'num_of_replies': 3},
#   {'author_id': 'UCLwTaD2vmFQoQNQv13ULLjw',
#    'author_name': 'md p',
#    'comment': 'Opppp',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC_0qK_J7afgTUulvF-7aFUw',
#    'author_name': 'ZeeSHAN AhmaD',
#    'comment': '1st   sada  sexy  raho  sattuu',
#    'published_date': '2 days ago (edited)',
#    'num_of_replies': None},
#   {'author_id': 'UC0PnhUlu7atI85-VVj0wjOQ',
#    'author_name': 'crickboy',
#    'comment': 'News wale achhe ho gaye to tu kya karega phir 🤣🤣',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UC3aHRl8zah5sYSSCItDcGJg',
#    'author_name': 'Aditya Nk',
#    'comment': 'Panchayat 💩💩💩💩',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCvlZ6FlbTmnseDyBEbms1qQ',
#    'author_name': 'jony',
#    'comment': 'Karoor darshan ne kiya hai ya sarway',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCVpq3BdF_WiFUtQtXHgru-A',
#    'author_name': 'Shaikh Nauman',
#    'comment': 'godi dalal media',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCgs2GxEI-qxBUTJvWwZxmIw',
#    'author_name': 'M  S',
#    'comment': 'Entertainment Hi Entertainment',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCHuoCchLZguKsUPCnAdm4pQ',
#    'author_name': 'Pradeep Sharma',
#    'comment': 'Hi',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCR_T1pIt0gTm8qZ9tYPbnEw',
#    'author_name': 'Rahul Jamra',
#    'comment': 'Kaua kyo roz pita h',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCun6LZ5cfdu0Q5sxZ84_T8w',
#    'author_name': 'A K',
#    'comment': 'Grrt',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCZnXy_b8NMvAh-BuXACYhsg',
#    'author_name': 'interesting stuff',
#    'comment': 'Ganja phonkne wale.... Tm Gujurat k musalmano k sath kab stand karoge??? Or kashmir main jo 70k + musalmano ko shaheed keya jaa chuka ha, unke sath stand kab karoge????',
#    'published_date': '1 day ago',
#    'num_of_replies': 5},
#   {'author_id': 'UCggKwgEYVk3SLMn-Wgj48Yg',
#    'author_name': 'Tanumay Mal',
#    'comment': 'Chewtiya media',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCHB7YL-L5tWJ6WerXn_EJRg',
#    'author_name': 'Sanjay Kumar',
#    'comment': 'Kitne main bike ho💩💩💩',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCzFo2xBU_ZrdT2rO9jMermg',
#    'author_name': 'Sanjay Sharma',
#    'comment': 'मुझे ड्रग्स दो,',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCd7Q6AezScKzf-2sm_hh2Gg',
#    'author_name': 'Moseen Ansari',
#    'comment': 'Febules',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCQWl_Ohmzlu4_dwdeiZQZUw',
#    'author_name': 'Faisal Husain',
#    'comment': 'Tihadi aur gullu ek sath dekhe Gaye kyunki is mamle mein dono sampadak jeil bhi ja chuke hai',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCktOdw1FrKh4kH19CKxJc1A',
#    'author_name': 'Valkyier911',
#    'comment': 'In',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCmZjwW_VAglBv0rCI8BVcBg',
#    'author_name': 'ankittyagityagi',
#    'comment': 'Farzi',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UC71k6xo9r0IZMjxRjfftGlA',
#    'author_name': 'Prince Solomon',
#    'comment': 'Very late',
#    'published_date': '2 days ago',
#    'num_of_replies': None},
#   {'author_id': 'UCDmKVUyu6iycroAfz4gypMg',
#    'author_name': 'Indrajeet Pandit Deepak',
#    'comment': 'Durr phite mu',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCaKITmHs8GggDoiXhjvdzJQ',
#    'author_name': 'Gyan world',
#    'comment': 'Jjjjj',
#    'published_date': '1 day ago',
#    'num_of_replies': None},
#   {'author_id': 'UCFN2AfzNW0Pk8cOmS_Lt35A',
#    'author_name': 'az khan',
#    'comment': 'Az',
#    'published_date': '2 days ago',
#    'num_of_replies': None}]}

# %%
import json
DIRECTORY_PATH = "D:/MSc Data Science/Elective Modules - Research Modules/[INF-DS-RMB] Research Module B/RM Code/Sentiment-Classification-Youtube-Comments-Political-Affiliation/"
json_file = os.path.join(DIRECTORY_PATH, "data/6. video_ids - Copy.json")

# %%
 with open(json_file, 'r') as fin:
    for line in fin:
        print("***************************************************************************")
        channel_videos = json.loads(line.rstrip())
        if 'video_ids' in channel_videos:
            print("Scraping comments from channel with id {} ".format(channel_videos['channel id']))
            list_video_ids = channel_videos['video_ids']
            
            print("list of video ids: ")
            print(list_video_ids)
# Out:
# ***************************************************************************
# Scraping comments from channel with id UCRvUQd-GsCR97qKReTE89jQ
# list of video ids:
# ['6HbQznTtpdc', 'eprgk89suP8', 'xPkhjBkXsUM', 'yFUIRd1XvAU', '8N3GvJZvUx0', 'ckstcCFUIfA', 'bwFtTZoY32Y', '84y_CX1t8NY']
# ***************************************************************************
# Scraping comments from channel with id UC7yoXZ7c8ZZAimgcqHBtHoQ
# list of video ids:
# ['T-0qtsQKUbA', 'GlZO3XWRa9k', 'xDzA_JomQAg', 'pmObIzzLoiE', '88gAa5x-9W4', 'zqdH0wyA6Ac', 'eIWcssVCii4', 'St37Fh-VpM4', 'PmwQ-tpXpCI', 'ScgyTG0rI3U', 'x1EHEG6_pc0', 'v_H9ns5Bt44', 'w1SPdbb9jMY', 'z0iodqhvnZo', 'ZIbKKvK6YOE', '0qOoxPq4SVo', 'gu_f7VttNr8', 'my8y1XsnEKg', 'yz7ldHwHWZg', 'bimdZj9AwKc', 'Ue4ofjUiTck', 'J11xe4TQVzo', 'sobYTbW600I', 'WF-W8n_rdyA', 'NkRaKlE9SOk', 'TMAaKnU2s2E', 'Hytx3vHI5Hg', 'JuZGoSGC5dw', 'u17JROxeklA', 'JtU9sQTeAmw', 'en2RCg33qko', 'j70-_UxpCDM', 'P6EMtY44lw4', 'VBfxRV7G9SU', '022Tpnw4UM8', 'YBhyVqt4Rng', 'pNRf3H4IGyU', 'HWqH9lOM5VQ', 'Lr20RzPNkCc', 'L5uOX_vY-oo', 'Hn09